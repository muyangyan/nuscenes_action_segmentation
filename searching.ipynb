# %%
import matplotlib.pyplot as plt
import tqdm
import numpy as np

from nuscenes.nuscenes import NuScenes
from nuscenes.map_expansion.map_api import NuScenesMap
from nuscenes.can_bus.can_bus_api import NuScenesCanBus

dataroot='/data/Datasets/nuscenes'

nusc = NuScenes(version='v1.0-trainval', dataroot=dataroot, verbose=True)
nusc_map = NuScenesMap(dataroot=dataroot, map_name='singapore-onenorth')
nusc_can = NuScenesCanBus(dataroot=dataroot)
# Out:
# ======
# Loading NuScenes tables for version v1.0-trainval...
# 23 category,
# 8 attribute,
# 4 visibility,
# 64386 instance,
# 12 sensor,
# 10200 calibrated_sensor,
# 2631083 ego_pose,
# 68 log,
# 850 scene,
# 34149 sample,
# 2631083 sample_data,
# 1166187 sample_annotation,
# 4 map,
# Done loading in 37.572 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 9.5 seconds.
# ======

# %%
len(nusc.scene)
nusc.scene
# Out:
# [{'token': '73030fb67d3c46cfb5e590168088ae39',
#   'log_token': '6b6513e6c8384cec88775cae30b78c0e',
#   'nbr_samples': 40,
#   'first_sample_token': 'e93e98b63d3b40209056d129dc53ceee',
#   'last_sample_token': '40e413c922184255a94f08d3c10037e0',
#   'name': 'scene-0001',
#   'description': 'Construction, maneuver between several trucks'},
#  {'token': 'c3e0e9f6ee8d4170a3d22a6179f1ca3a',
#   'log_token': '6b6513e6c8384cec88775cae30b78c0e',
#   'nbr_samples': 40,
#   'first_sample_token': '9e28820bd2ba4eb480e1b9079f17c30c',
#   'last_sample_token': 'd0dc3c18dfc64c779bc9e4ee6e9e2e3b',
#   'name': 'scene-0002',
#   'description': 'Intersection, peds, waiting vehicle, parked motorcycle at parking lot'},
#  {'token': 'e7ef871f77f44331aefdebc24ec034b7',
#   'log_token': '92af2609d31445e5a71b2d895376fed6',
#   'nbr_samples': 40,
#   'first_sample_token': 'fd8420396768425eabec9bdddf7e64b6',
#   'last_sample_token': '20684b77c01641e7a5ada48308a0b1e1',
#   'name': 'scene-0003',
#   'description': 'Parking lot, barrier, exit parking lot'},
#  {'token': '25496f19ffd14bd088cb430bfc01a4d7',
#   'log_token': '47620afea3c443f6a761e885273cb531',
#   'nbr_samples': 40,
#   'first_sample_token': '556a590f3e1741fb87d7e4dc8ea687e4',
#   'last_sample_token': '5ece1620df164d8b9e8867a9ae1d38b0',
#   'name': 'scene-0004',
#   'description': 'Random scene, arrive at intersection, cross intersection, jaywalkers'},
#  {'token': '6f5133fe62b240e797bac25aeff8b531',
#   'log_token': '47620afea3c443f6a761e885273cb531',
#   'nbr_samples': 39,
#   'first_sample_token': '633212bb7ffa4953ac240019c9de2414',
#   'last_sample_token': '28931837b96340ba84823cd4c6845780',
#   'name': 'scene-0005',
#   'description': 'Overtaken by taxi, construction site'},
#  {'token': '7deb4760e2244f32b57f9d631b535b66',
#   'log_token': '47620afea3c443f6a761e885273cb531',
#   'nbr_samples': 40,
#   'first_sample_token': '7ba9d78d92914fd5a204d3bc1233bd4e',
#   'last_sample_token': '93c29cde985a47adaabe3402522dce76',
#   'name': 'scene-0006',
#   'description': 'Sitting construction worker, parked bicycle, ped walking along road, construction vehicle, worker sitting on back of van'},
#  {'token': 'bc219c0fa63b43b4b9dddab47fce1fef',
#   'log_token': '47620afea3c443f6a761e885273cb531',
#   'nbr_samples': 39,
#   'first_sample_token': '568df10a9f1b48ca8f79b4b534e28b54',
#   'last_sample_token': '53848df7ecbb4d9796135c43576eb054',
#   'name': 'scene-0007',
#   'description': 'Van overtaking us, peds, jaywalker, bicycle rack, turn left'},
#  {'token': '9a61a88ed9094334a73aa93c08222110',
#   'log_token': '47620afea3c443f6a761e885273cb531',
#   'nbr_samples': 40,
#   'first_sample_token': 'cb58ac9c08e244d3a96feb126da39d0f',
#   'last_sample_token': 'e7fdedf7efcc430aa0985791dfb4f98f',
#   'name': 'scene-0008',
#   'description': 'Several moving pedestrians, parked cards and motorcycle'},
#  {'token': 'dd61533869aa48f2aaa7e8a6418bdbe6',
#   'log_token': '47620afea3c443f6a761e885273cb531',
#   'nbr_samples': 40,
#   'first_sample_token': '29a1e9bcb75740479cd5acdfa88b2cfd',
#   'last_sample_token': '9b5b6ccd74d44b519794b2a49c6d8806',
#   'name': 'scene-0009',
#   'description': 'Peds crossing, parked cars, garbage, peds waiting'},
#  {'token': 'daa9fce50073470398da3c2bccdaf21b',
#   'log_token': '47620afea3c443f6a761e885273cb531',
#   'nbr_samples': 40,
#   'first_sample_token': '9872af6e56ba49e39c7529fb3bbd63ce',
#   'last_sample_token': '38af3c82bc3345d5bb5c681f87d46d16',
#   'name': 'scene-0010',
#   'description': 'Parked motorcycle, person pickung up garbage, pass construction vehicles and entrance to construction site'},
#  {'token': 'c075fbdd97124beaba95bc5c25149f30',
#   'log_token': '47620afea3c443f6a761e885273cb531',
#   'nbr_samples': 40,
#   'first_sample_token': '538d60ddf0014c268ee1efbec35289a1',
#   'last_sample_token': '9fe4ebc85e7d4bd697a956aa3d244e6b',
#   'name': 'scene-0011',
#   'description': 'Turn left, pass trucks on both sides, construction workers, sleeping construction workers, garbage, parked cars'},
#  {'token': '265f002f02d447ad9074813292eef75e',
#   'log_token': 'd31dc715d1c34b99bd5afb0e3aea26ed',
#   'nbr_samples': 40,
#   'first_sample_token': '88a090c54cc844cc878f00d08274a683',
#   'last_sample_token': 'feedde26563b4303ad0faa7ef7684940',
#   'name': 'scene-0012',
#   'description': 'Nature, bus stop, parked cars, bus exits from the intersection'},
#  {'token': '41fde20fedcd4d22ab26811688612870',
#   'log_token': 'd31dc715d1c34b99bd5afb0e3aea26ed',
#   'nbr_samples': 40,
#   'first_sample_token': 'b9c60cfaf1814c8bb363037dec7abd35',
#   'last_sample_token': '51f7ea7d3e4e42dfaf183dbe9996f1fb',
#   'name': 'scene-0013',
#   'description': 'Follow bus, parked cars, trash cans, parked bicycles, nature'},
#  {'token': 'd1e57234fd6a463d963670938f9f556e',
#   'log_token': 'd31dc715d1c34b99bd5afb0e3aea26ed',
#   'nbr_samples': 40,
#   'first_sample_token': '43cfc03be6f842ae8942c995f8e3f2fb',
#   'last_sample_token': 'd0501e0542884ab1a4790236b16bc1d4',
#   'name': 'scene-0014',
#   'description': 'Follow bus, cross intersection, nature'},
#  {'token': '813213458a214a39a1d1fc77fa52fa34',
#   'log_token': 'd31dc715d1c34b99bd5afb0e3aea26ed',
#   'nbr_samples': 40,
#   'first_sample_token': '234b0f37af694571876a745e5bbb5e08',
#   'last_sample_token': '8a96bc21f4fa46d392daea4db4814547',
#   'name': 'scene-0015',
#   'description': 'Narrow road, following bus, bus on opposite lane, parked cars'},
#  {'token': 'efa5c96f05594f41a2498eb9f2e7ad99',
#   'log_token': 'd31dc715d1c34b99bd5afb0e3aea26ed',
#   'nbr_samples': 40,
#   'first_sample_token': 'fbd3aa2098234fb1869d34d920e16eda',
#   'last_sample_token': '9cdae13a6a0545d8a2fc50c06d993c7e',
#   'name': 'scene-0016',
#   'description': 'Turn left, people on both sides, parked vans'},
#  {'token': '3dd9ad3f963e4f588d75c112cbf07f56',
#   'log_token': 'd31dc715d1c34b99bd5afb0e3aea26ed',
#   'nbr_samples': 40,
#   'first_sample_token': '134c7f63827c4b858a2a4ce0582d8f6e',
#   'last_sample_token': 'd995c004834a4c4eb5ef3c7dbefc720a',
#   'name': 'scene-0017',
#   'description': 'Barriers, peds, arriving at busy intersection'},
#  {'token': 'b51869782c0e464b8021eb798609f35f',
#   'log_token': 'd31dc715d1c34b99bd5afb0e3aea26ed',
#   'nbr_samples': 40,
#   'first_sample_token': 'f0e4797551024f9487a016ee9d9e29e1',
#   'last_sample_token': '59e1ec0333a747d58efe81aeb250c113',
#   'name': 'scene-0018',
#   'description': 'Merge left, turn into unloading zone'},
#  {'token': 'de943e246dad4ad686de98008a634ecf',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': 'b7d39e03124a49c69083bb6b8b23ce38',
#   'last_sample_token': 'afaf41b80a66437ab1235fe6cb6a2ecd',
#   'name': 'scene-0019',
#   'description': 'Turn left, waiting peds, turn left'},
#  {'token': '4d475873416a4860900f5af213e0027c',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 39,
#   'first_sample_token': '517a07a7eea34fb6b8fbee028840ec87',
#   'last_sample_token': 'b8c1727432364080b983d322a2752dcb',
#   'name': 'scene-0020',
#   'description': 'Turn right, walking peds, pedestrian in blind spot in couple of frames, car park exit'},
#  {'token': '03ee880dd4e348f4b3407f0d073c7c70',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '46f7968fb3d94da1a35cee3fd2cdd9c7',
#   'last_sample_token': '04a58655c5f847118011c66becbf23b8',
#   'name': 'scene-0021',
#   'description': 'Wait at intersection, jaywalkers, parking lot, parked bicycle, turn right, construction, truck'},
#  {'token': '7e3a6bdd6c6f4c8fb018cff404974446',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '1247776e94cd4c2999df4d8cf07b43ee',
#   'last_sample_token': '328fd8f2e946430b9b2b83f75dbc67fd',
#   'name': 'scene-0022',
#   'description': 'Barriers, construction, lane switch, turn left'},
#  {'token': 'd0880a386b6d434bb5cd13c134af7a3e',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': 'a085faf3366241a095a88d527a3fdc1b',
#   'last_sample_token': '09c20b036021493ea64c166cd51ac14c',
#   'name': 'scene-0023',
#   'description': 'Overtake parked car, bus turning, motorcycle'},
#  {'token': 'd7ebcbbd26d849b384c11bec8df28a9b',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '73c04e824a214a54922b03391a1549f3',
#   'last_sample_token': 'ab67269ee29f4f558d17f0e987c9af5f',
#   'name': 'scene-0024',
#   'description': 'Intersection, peds in cafe, parked motorcycle, ped crossing'},
#  {'token': '0c601ff2bf004fccafec366b08bf29e2',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '3e755d84f9634ee780b76847cd0f917b',
#   'last_sample_token': 'fb6c1ea5f03746fab2ceca823c537f4e',
#   'name': 'scene-0025',
#   'description': 'Ped crossing street in front of ego vehicle'},
#  {'token': 'b79d940da8df43d09ee972c2414ffeca',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 39,
#   'first_sample_token': '4f54fd98c3e4467a91767d7bfc9f30d8',
#   'last_sample_token': '5c61b4ffdfc34d8789ebfb518cdbfea5',
#   'name': 'scene-0026',
#   'description': 'Parked cars, peds on the roadside'},
#  {'token': '1d4db80d13f342aba4881b38099bc4b7',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '758ed7a3a37f4b66a4e0dfcb7e16d06b',
#   'last_sample_token': '2ab351dd2aa44cc59b4df94feb2b5fa1',
#   'name': 'scene-0027',
#   'description': 'Delivery motorcycle turns left, veh turn right'},
#  {'token': '3a1850241080418b88dcee97c7d17ed7',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': 'e5fd1a6e14a448a1aba85e60b763f605',
#   'last_sample_token': '159259786fa9452984a95541fa7ec1ed',
#   'name': 'scene-0028',
#   'description': 'Taxi parked on road, bicycle rack, many peds, many jaywalkers, parked bicycles, ped exiting taxi, ped crossing traffic light, lane change, peds crossing crosswalk'},
#  {'token': '6520b5f0d568414c973f791b30ee1548',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '20d3a69979874bae88d539b06e3d103a',
#   'last_sample_token': '91e81904bc56431ca8cb32441cb84776',
#   'name': 'scene-0029',
#   'description': 'Waiting, peds crossing intersection'},
#  {'token': '82aef599650d462db73731b7ff40918b',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': 'bb972993952a499d8ed1a19fb2c52dd2',
#   'last_sample_token': 'dd3d6515f2f54fc489c81a814713a8e7',
#   'name': 'scene-0030',
#   'description': 'Two parked motorcycles, overtake'},
#  {'token': 'f444b757d7e2444c889da10f02b73491',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '64dd47bcaabc44279c9be12aab064752',
#   'last_sample_token': '25bb601da8f74d6aadf9cbc447d3c0bb',
#   'name': 'scene-0031',
#   'description': 'Construction, workers sitting on grass, garbage'},
#  {'token': '9047b53fd41540649dce014a128cbe1b',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '9aaa0c5d15694673871772c685fbfae5',
#   'last_sample_token': '401897a3cda547d983c51b5eb588597e',
#   'name': 'scene-0032',
#   'description': 'Turn left, motorcycle driving, ped sitting'},
#  {'token': '6e81ee0f64274490a403bbd6482c2bf9',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 40,
#   'first_sample_token': '3a77c8c2fa724db784cf3513d1a29cac',
#   'last_sample_token': '7f768fc8681d448db27638d18914d991',
#   'name': 'scene-0033',
#   'description': 'Low traffic, following bus'},
#  {'token': 'bb73edb93a0a46c4be997c576e9beb61',
#   'log_token': 'bc41a49366734ebf978d6a71981537dc',
#   'nbr_samples': 39,
#   'first_sample_token': 'b8aea4184f244ea1a9c9d1ed01ddcf21',
#   'last_sample_token': '3e1d40ecbb3142689ba1b8e4d8d955d4',
#   'name': 'scene-0034',
#   'description': 'No traffic, dead end street, overtake parked truck'},
#  {'token': '3dd2be428534403ba150a0b60abc6a0a',
#   'log_token': '783683d957054175bda1b326453a13f4',
#   'nbr_samples': 40,
#   'first_sample_token': 'd62b0f9db06440c695781c52ed71909a',
#   'last_sample_token': '2f598ed435a94ed1a58f8523592cefb4',
#   'name': 'scene-0035',
#   'description': 'Parking lots, trash can, bump, scooter, peds, potential jaywalkers, bus stop, oncoming bus'},
#  {'token': '5a0dd8908a3a459b83ec5eb6ac7d0f82',
#   'log_token': '783683d957054175bda1b326453a13f4',
#   'nbr_samples': 40,
#   'first_sample_token': 'e1b5c775be134db696ce22413d195c72',
#   'last_sample_token': '95b0c6a3602544ffb3c3e014b2cdfda6',
#   'name': 'scene-0036',
#   'description': 'Parked bicycle, construction, peds, workers, construction vehicle, bike racks'},
#  {'token': '2f56eb47c64f43df8902d9f88aa8a019',
#   'log_token': '783683d957054175bda1b326453a13f4',
#   'nbr_samples': 40,
#   'first_sample_token': '0f39f34febc84a6689f08599105d1421',
#   'last_sample_token': '57a80885dce842049aa03cd95ccca916',
#   'name': 'scene-0038',
#   'description': 'Parked construction vehicles, peds, garbage'},
#  {'token': '8edbc31083ab4fb187626e5b3c0411f7',
#   'log_token': '783683d957054175bda1b326453a13f4',
#   'nbr_samples': 40,
#   'first_sample_token': '15c59626df6b4f96bb7ef7c5c1797159',
#   'last_sample_token': 'c1b68aa96280460c85bff795ce202a86',
#   'name': 'scene-0039',
#   'description': 'Busy street, parked cars, parking lot, ped sitting at bus stop, motorcycle driving'},
#  {'token': '359f9c029ae44e1d9d47c05bc7915561',
#   'log_token': 'd7fd2bb9696d43af901326664e42340b',
#   'nbr_samples': 40,
#   'first_sample_token': '1315ebfd98fd43f4894a95eea2a41761',
#   'last_sample_token': '302fa5e1a4394b158800a0bd289e54b3',
#   'name': 'scene-0041',
#   'description': 'Turn left, arrive at busy intersection, red light'},
#  {'token': 'c6c092a66329470f836714f46b92d59b',
#   'log_token': 'd7fd2bb9696d43af901326664e42340b',
#   'nbr_samples': 41,
#   'first_sample_token': '9f03829b02694c17a98fbcb20a9d66cc',
#   'last_sample_token': '3a91df4f75bc48b893369bdcb4030984',
#   'name': 'scene-0042',
#   'description': 'Parked cars, many peds, parked bicycles, trash can, parking lots'},
#  {'token': '70368a18644046f898ab836fc8a3c03f',
#   'log_token': 'd7fd2bb9696d43af901326664e42340b',
#   'nbr_samples': 39,
#   'first_sample_token': '7ec5350531b74c35a02877ce8314a8d5',
#   'last_sample_token': 'ab51516d2c3b4a0991c04f1528c7bc74',
#   'name': 'scene-0043',
#   'description': 'Busy intersection, oncoming traffic, construction zone on the left'},
#  {'token': '8758419c03ab47a59ea6d6620176f3a3',
#   'log_token': 'd7fd2bb9696d43af901326664e42340b',
#   'nbr_samples': 40,
#   'first_sample_token': '1dda3d57404f4057af294145ba7332f6',
#   'last_sample_token': '8ddfde23694a4dec815f8aaaf8125d5a',
#   'name': 'scene-0044',
#   'description': 'Truck turns, parked cars, bump, bikes'},
#  {'token': 'eac3102e4cc24d4b95532bcc711a902f',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 39,
#   'first_sample_token': '5bfd9c26f8364a578faf16bdb96049ea',
#   'last_sample_token': '3c0321e992564ff19f927d0cde5b1669',
#   'name': 'scene-0045',
#   'description': 'Full parking lot, peds, exiting from car park'},
#  {'token': '798e8504b4364d378270333a349ef508',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 39,
#   'first_sample_token': 'de78abb899bf4429a2e1a4cfe8709cc2',
#   'last_sample_token': 'f19a3c65dc7d4affbac8454665ace826',
#   'name': 'scene-0046',
#   'description': 'Busy intersection, ped crossing, waiting for traffic light, construction zone on the left'},
#  {'token': '4047f251c21a475abb49518e0fa6fa9e',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 40,
#   'first_sample_token': '2b946a3f99fc479aac0f470b284199a0',
#   'last_sample_token': '95602fd0ecff446398008115dfbe1feb',
#   'name': 'scene-0047',
#   'description': 'Construction workers close to road, vehicle turn out, cross intersection'},
#  {'token': 'cf550d9670274ac1a7f274fbacb39c48',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 40,
#   'first_sample_token': '29c1c29d330746488a5ba7cfb66cdb33',
#   'last_sample_token': '9b6ec24f02604f03be62455832f8a596',
#   'name': 'scene-0048',
#   'description': 'Construction, narrow road, construction workers, heavy construction vehicles, right turn'},
#  {'token': '095d9b93b583425f910ae2afaf1d017d',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 39,
#   'first_sample_token': '923c402a3b144655858d07292ebb44c8',
#   'last_sample_token': '8167a69cab9a468db7a66dfb5dcfc382',
#   'name': 'scene-0049',
#   'description': 'Construction, barriers behind net, parked trucks, excavators, turn left'},
#  {'token': '9a81caa3d5134d7f87ee4786ccef68f7',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 39,
#   'first_sample_token': '990723056b344e0bbc58cf3faffdaecf',
#   'last_sample_token': 'd7e9b28136e048278c1cda3abefb45dc',
#   'name': 'scene-0050',
#   'description': 'Narrow street, seveal peds, shadows, turn left, parked motorcycle'},
#  {'token': '0e37d4a357db4246a908cfd97d17efc6',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 39,
#   'first_sample_token': 'bc14cdca19c748bc8b409812ba1f86f0',
#   'last_sample_token': 'b0302700a2994d1aa238d93c59e329d1',
#   'name': 'scene-0051',
#   'description': 'Pass parked vehicles, peds, arrive at intersection'},
#  {'token': '37b32e4e8cf846679b2c0cb342dbd4aa',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 40,
#   'first_sample_token': '171c637d2681463fad3bf01068fab647',
#   'last_sample_token': 'd2f63505f315460c80b7a54560e2a8ea',
#   'name': 'scene-0052',
#   'description': 'Oncoming car in the same lane, overtake parked car, turn left'},
#  {'token': '6d4b2bd795ae4c66900ad98ccd2371a6',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 39,
#   'first_sample_token': '2cc9075f8e4348fb922c712ffd3fee12',
#   'last_sample_token': '7578fde40f7d4accb58869ae991e54d7',
#   'name': 'scene-0053',
#   'description': 'Cross intersection in group of cars, peds, bike rack'},
#  {'token': '8b43539a55374b6c8ed60c95a42d63a2',
#   'log_token': 'f38ef5a1e9c941aabb2155768670b92a',
#   'nbr_samples': 39,
#   'first_sample_token': '5a90f3de10f246a49abc1035cda648be',
#   'last_sample_token': 'a71e9652177b4e2cbd285ec59b2f6d4d',
#   'name': 'scene-0054',
#   'description': 'Turn left, many parked heavy trucks, workers'},
#  {'token': '446af4b1d7da4735a607bc3e45c2e0b3',
#   'log_token': '7e25a2c8ea1f41c5b0da1e69ecfa71a2',
#   'nbr_samples': 40,
#   'first_sample_token': 'f3e1d807c1784a2c8adfb80952ca5098',
#   'last_sample_token': '00fd7d81fe4a4ea684e14ed50d5a37b8',
#   'name': 'scene-0055',
#   'description': 'Bus stop left, parked cars right, oncoming bus'},
#  {'token': '83773bcf46ac486383529098de0542dd',
#   'log_token': '7e25a2c8ea1f41c5b0da1e69ecfa71a2',
#   'nbr_samples': 41,
#   'first_sample_token': '2c0f9d4e41b544d59ba5d26185c5f546',
#   'last_sample_token': '6b3aaffb0c4b4bc7ac41806dfd2a9e9d',
#   'name': 'scene-0056',
#   'description': 'Peds, nature, construction, trash can, parked truck, turn right'},
#  {'token': '433a14f8dcf5457fb2c4def5c749122a',
#   'log_token': '7e25a2c8ea1f41c5b0da1e69ecfa71a2',
#   'nbr_samples': 39,
#   'first_sample_token': '07900d5585594008b24500c059f30677',
#   'last_sample_token': 'af5229d9f3df4e719023cb516e87cbd9',
#   'name': 'scene-0057',
#   'description': 'Jaywalkers, parked bike and scooter, parked car on the main road'},
#  {'token': '9a1188aba4bf458c8220818a6c0be55a',
#   'log_token': '7e25a2c8ea1f41c5b0da1e69ecfa71a2',
#   'nbr_samples': 39,
#   'first_sample_token': '325b2cf83d0948cbbe968de2bad19578',
#   'last_sample_token': '1af83b81a1bf4536a7a54b0b7c464f6e',
#   'name': 'scene-0058',
#   'description': 'Construction, strange cleaning vehicle parked on our lane'},
#  {'token': 'dcd5bc29543747e28ef02816dd458290',
#   'log_token': '7e25a2c8ea1f41c5b0da1e69ecfa71a2',
#   'nbr_samples': 41,
#   'first_sample_token': 'cf48ec22ab4e4d6e9eddb46f0fbb0b9e',
#   'last_sample_token': '55fae959b104482b9f87533319e02e2f',
#   'name': 'scene-0059',
#   'description': 'Wait at intersection, bike on sidewalk, worker blowing leaves'},
#  {'token': 'bb028034cb474e3da8953f83752a70a9',
#   'log_token': '7e25a2c8ea1f41c5b0da1e69ecfa71a2',
#   'nbr_samples': 40,
#   'first_sample_token': 'be4da7572df94b7cace70800d4171cb6',
#   'last_sample_token': 'eb841bf14dca4c8daa8c2110a2e4768e',
#   'name': 'scene-0060',
#   'description': 'Wait at intersection, bike on sidewalk, worker blowing leaves, bicycle crossing'},
#  {'token': 'cc8c0bf57f984915a77078b10eb33198',
#   'log_token': '7e25a2c8ea1f41c5b0da1e69ecfa71a2',
#   'nbr_samples': 39,
#   'first_sample_token': 'ca9a282c9e77460f8360f564131a8af5',
#   'last_sample_token': 'ed5fc18c31904f96a8f0dbb99ff069c0',
#   'name': 'scene-0061',
#   'description': 'Parked truck, construction, intersection, turn left, following a van'},
#  {'token': '762e6aac0d6f4c1b9b0286ab4b2da654',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 39,
#   'first_sample_token': '9cd981bf4a4547bc97c62058f5291d92',
#   'last_sample_token': 'b986b0bd1ad64f70b85307972bffdca8',
#   'name': 'scene-0062',
#   'description': 'Change lane, parked cars, overhead walkways'},
#  {'token': 'a8819942e8bb43b6a832c56dfb78cfc6',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 39,
#   'first_sample_token': 'dc53f0d721694157832cc9fc73daa275',
#   'last_sample_token': 'eacae173a84341ef99ed1e504ee8c5ce',
#   'name': 'scene-0063',
#   'description': 'Exit passage, parking lot, flag, trucks, wait at intersection'},
#  {'token': '7ad94b6e54f641208bf59cba6bb55220',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': '5718fa033dad4893bd1f6e6720e5dd5a',
#   'last_sample_token': '07a022e7759a462aaab2e9bab0b9dd42',
#   'name': 'scene-0064',
#   'description': 'Parking lots, oncoming special electrical vehicle'},
#  {'token': '59530445fcc04c2090bfaf63f342f794',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'a805936597f243a38745c2e8bcadf378',
#   'last_sample_token': 'd51683a5d04540968046c8c27981be9f',
#   'name': 'scene-0065',
#   'description': 'Wait at intersection, truck, peds, turn right, parking lot'},
#  {'token': '30e77a3561ce4f1bb4fd90e322ea29d7',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 39,
#   'first_sample_token': 'a262ad95f9e44fad8a369c707fe75dec',
#   'last_sample_token': '45be071350e7496ba5158b08ed808f72',
#   'name': 'scene-0066',
#   'description': 'Parking lots, parked truck, construction, congestion, worker directing traffic, passing cars'},
#  {'token': 'cb0cd06a1dd84271968466d7b65e48f8',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': '0a71cd9e2ee94dfda79f9d87df741bba',
#   'last_sample_token': 'bb778ab188a3477f9673cce754fceb5d',
#   'name': 'scene-0067',
#   'description': 'Exit construction, ped on crosswalk, construction workers, parking lot'},
#  {'token': 'b0b26c1e5a1140e69598422f12ae1dc0',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 39,
#   'first_sample_token': 'db655797a4be45e69c6d0c11b07012c9',
#   'last_sample_token': 'd5fe241009d44048a5b353ea62991d0f',
#   'name': 'scene-0068',
#   'description': 'Two turning trucks, wait, turn left'},
#  {'token': 'a5d7cc4bf3404cccb89932d94ccb9da6',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'ff3e47f0101749cb995e64f97d237305',
#   'last_sample_token': 'ea0fd790654b417fa8501ed27691e470',
#   'name': 'scene-0069',
#   'description': 'Turn left, peds near parked bus, bird'},
#  {'token': 'c0cb50847c3949a0b4baf2e200ac897c',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': '79caf3784b924bcfb74d2676c3b5dcdb',
#   'last_sample_token': '55a2bbbcad7b4781b5c8d13aacc87cd8',
#   'name': 'scene-0070',
#   'description': 'Peds, ped with bag, bus stop, parking lot, turn right, follow cyclist, trailers, turn left'},
#  {'token': '860ef56791a947baadb27dd00bd5d4b3',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'f76dc79b39874904994b30384c70275f',
#   'last_sample_token': '9d6823596eb14499a9d7223ecd25047a',
#   'name': 'scene-0071',
#   'description': 'Parked trucks, construction vehicles, road blocked relative to baseline route, find deviation'},
#  {'token': 'fbf27198b3424e28ab1de2a12eb3dc4a',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': '1100b838ee544231a494089ce390f503',
#   'last_sample_token': 'a011c05eedf445ef99fb2f31e90b1774',
#   'name': 'scene-0072',
#   'description': 'Wait at intersection, running ped'},
#  {'token': '5557f4edc1464442812293e2ea90a586',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'ee43cd05608e4e9e9f741d38397c2131',
#   'last_sample_token': '6a5df9ab3df04fd680599b46ba6f0521',
#   'name': 'scene-0073',
#   'description': 'Parked scooter, flock of pigeons, person sitting on top of bench, two trucks passing, turn right'},
#  {'token': '78c5f7d7b547483c906d8524a8c3190f',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': '307ba1f86fd14cd18b118ac823a43f9e',
#   'last_sample_token': 'c49cbb185f9044719ea4cce3955caf39',
#   'name': 'scene-0074',
#   'description': 'Wait at intersection, turn left, bike rack, parked cars, peds'},
#  {'token': '01c3f5e39956402da3e37845632fadca',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 39,
#   'first_sample_token': '03b428b824ef4fa5a2616198036c35c6',
#   'last_sample_token': 'ab4fd22d24274174841183521d7a1a35',
#   'name': 'scene-0075',
#   'description': 'Parked cars, oncoming semi, two oncoming bikes, parked motorcycle, bike rack'},
#  {'token': 'e9a94a93c36a4adb831eb67ec8bdf289',
#   'log_token': '7a0fde44c3504eaeb18f9ad83bed65bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'f4c4a1d61cd14f16b3e95c43aee83d5a',
#   'last_sample_token': '7db920e252e9423d87f2f64150e8718c',
#   'name': 'scene-0076',
#   'description': 'Turn right, follow cyclist, turn right'},
#  {'token': '7365495b74464629813b41eacdb711af',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': '8e46878ced734164aae0e83567aa02a5',
#   'last_sample_token': 'f6dc7d8ea5bd4b84938579f60488bee5',
#   'name': 'scene-0092',
#   'description': 'Drive through passage, peds walking alongside lane'},
#  {'token': 'cba3ddd5c3664a43b6a08e586e094900',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': '6e0955c28ecb405b98d91b089761dbbb',
#   'last_sample_token': 'f6a82d4677144b92bcce7d8a013889a8',
#   'name': 'scene-0093',
#   'description': 'Turn right, parking lots, cross intersection'},
#  {'token': '91c071bcc1ad4fa1b555399e1cfbab79',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': '19ffc60b7e9f429cbca0dbd5e2fc2e03',
#   'last_sample_token': '8887f956960c40df8e801576ad31ac93',
#   'name': 'scene-0094',
#   'description': 'Oncoming cyclist, cars, wait at intersection'},
#  {'token': 'b4b82c4d338a4b6d86835388ce076345',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': '78be3bd5f1f146cdb1b7120bbf8a218c',
#   'last_sample_token': '15e8288c2e60438bb4d65702ff0df804',
#   'name': 'scene-0095',
#   'description': 'Wait at intersection, peds occluded, start driving'},
#  {'token': '68e79a88244f447f993a72da444b29ba',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': 'f9475d1f1f96401c81ce511a93578a96',
#   'last_sample_token': '39a5d8e9868d4dcd9cf8386068c903b3',
#   'name': 'scene-0096',
#   'description': 'Cross busy intersection, cyclist nearby, construction barriers and cones'},
#  {'token': '2eb4d7f00e584a548aa0b899638bfb0a',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': '1c81b06c812b47788462c31f58b6c1d0',
#   'last_sample_token': '2f26712f9c484ced857e42dc425d1d20',
#   'name': 'scene-0097',
#   'description': 'Wait at red light, turns green, cross intersection'},
#  {'token': 'c65c4acf86954f8cbd53a3541a3bfa3a',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': 'c292d90b90ec4dbd826dfd11aa361df1',
#   'last_sample_token': '59b048ee1ed2466c973e45f9e79ce5d1',
#   'name': 'scene-0098',
#   'description': 'Parked cars, peds, bus stop, bicycle rack, sign trailer, bicyclist, ped carrying object, bridge'},
#  {'token': '5af9c7f124d84e7e9ac729fafa40ea01',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': 'b9db804449d34414ba98868e9034abd3',
#   'last_sample_token': 'cae55f0935cb448d9527042acf104ad0',
#   'name': 'scene-0099',
#   'description': 'Parked vans, switch lane, construction zone in the right, bike following in rear, passed by active motorcycle'},
#  {'token': 'afd73f70ff7d46d6b772d341c08e31a5',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': '028a3f3a237e469cb099f6d9c8e7f2f4',
#   'last_sample_token': '3e743a8cf0394f33b45a4c15149d014b',
#   'name': 'scene-0100',
#   'description': 'Wait at red light, oncoming cyclist, peds, parked bicycle, parked construction car'},
#  {'token': '01452fbfbf4543af8acdfd3e8a1ee806',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': 'd5324133e1d241658a7b763831b3af2e',
#   'last_sample_token': '21971c1ec4644d608f8c08bbfd4059f7',
#   'name': 'scene-0101',
#   'description': 'Concrete mixer spinning, traffic cones, wait at red light, move onto bridge, lane change'},
#  {'token': 'ddb615d9bb22484cabc6545b632a1025',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': '806011e8a7114eca971fd0f6b95bcd4b',
#   'last_sample_token': '7844c7bf21ce4114a8ef64b3a46a579b',
#   'name': 'scene-0102',
#   'description': 'Turn right at intersection, cross bridge, many peds'},
#  {'token': 'fcbccedd61424f1b85dcbf8f897f9754',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': '3e8750f331d7499e9b5123e9eb70f2e2',
#   'last_sample_token': '281b92269fd648d4b52d06ac06ca6d65',
#   'name': 'scene-0103',
#   'description': 'Many peds right, wait for turning car, long bike rack left, cyclist'},
#  {'token': 'c525507ee2ef4c6d8bb64b0e0cf0dd32',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': 'f1b7b463072e4630b2c1d5ba8b6cd50b',
#   'last_sample_token': '0228b4e5617c49ec8ac0b433fd1c80ba',
#   'name': 'scene-0104',
#   'description': 'Start car, cross intersection, skyscraper occluded by traffic light, parked bicycles, parked cars, cross intersection'},
#  {'token': '2ed0fcbfc214478ca3b3ce013e7723ba',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': '8d56b71c09c04ece827107b3c103498f',
#   'last_sample_token': 'b38a121a8c4549a69abe0fdeff766bba',
#   'name': 'scene-0105',
#   'description': 'Parking lots, peds, parked cars, cars on elevated bridge, truck'},
#  {'token': 'bed67ef03c4a4066a74f6c0117d512ee',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': '04ebf63518914e0883bdffdb0b6c3f4c',
#   'last_sample_token': 'b4ee26d84a884b6fb2b47dd16f612a66',
#   'name': 'scene-0106',
#   'description': 'Drive between buildings under construction, slow down at intersection, several traffic cones and temporary barriers'},
#  {'token': '3b2ee26cb8484f77895bc336663df502',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': 'ad8905836f364a87a7233eb0aef915ea',
#   'last_sample_token': '1ed7231fca1748c3b697f29af4d9bc76',
#   'name': 'scene-0107',
#   'description': 'Cross busy intersection, bendy bus changing lane'},
#  {'token': 'a178a1b5415f45c08d179bd2cacdf284',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 39,
#   'first_sample_token': '339ead96177c4e338fde8235c188cfaa',
#   'last_sample_token': '8d2cb1af003e4f009f779d79cfbe27b2',
#   'name': 'scene-0108',
#   'description': 'Construction zone, waiting for car to pass, turn right'},
#  {'token': 'fb73d1a6c16147ee9416faf6b310fadb',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': '4d0d06979c984a72bfb9e6c5e3a35f84',
#   'last_sample_token': 'daf998de0f354de4850f63d06a79d2b5',
#   'name': 'scene-0109',
#   'description': 'Cross roundabout, construction vehicle, ped walking along the road side'},
#  {'token': 'd87ec0461e3f4c4ea29b0f0c0ede5167',
#   'log_token': '53cf9c55dd8644bea67b9f009fc1ee38',
#   'nbr_samples': 40,
#   'first_sample_token': '80c91574d0174206a74435200aba8ba8',
#   'last_sample_token': '741bbef66bca4f969a3d114ea0236f54',
#   'name': 'scene-0110',
#   'description': 'Parked car with open bonnet, parked cars, oncoming truck, oncoming cyclists'},
#  {'token': 'a1ca2ba59ac9452fb3da60019bf32c71',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'b3e41a510a2c4af09fcaf208ea45cf9c',
#   'last_sample_token': '77da9195ccec4ab788985091d5d52615',
#   'name': 'scene-0120',
#   'description': 'Parked motorcycles, parking lot, wait at intersection, truck, ped very close to ego-vehicle'},
#  {'token': 'ce2d6bdc33084dc1a2780f41f6740e06',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': '952fe3dccc434805a99d4177199e5992',
#   'last_sample_token': '6ede2843a76347d0bffb268a305d2be8',
#   'name': 'scene-0121',
#   'description': 'Peds, follow motorcycle, motorcycle turns right'},
#  {'token': 'e6cb595f6df44b3999db28c65f2244ac',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 39,
#   'first_sample_token': '36226a7d173a4992bb4e0be0779daad7',
#   'last_sample_token': '4f7ba3d9224b4577ac5081903727ed67',
#   'name': 'scene-0122',
#   'description': 'Fast motorcycle on street ahead, stop, parked bicycles, turn right'},
#  {'token': 'cb3ef7b7ef124983b336c781f134cdfb',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'bd4481f6eb3f4140aae47cb767671b12',
#   'last_sample_token': '33673e8b71b54b6b8aba19674c4d364b',
#   'name': 'scene-0123',
#   'description': 'Monument, truck, peds, turn left, downhill'},
#  {'token': 'bed8426a524d45afab05b19cf02386b2',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'f13681c5baa842e18612875866994266',
#   'last_sample_token': '9b319d72e7ef429faf15c9cf0b0863b1',
#   'name': 'scene-0124',
#   'description': 'Many peds, parked buses, parked cars'},
#  {'token': '36fbee38a28543ea9e27a67d64e1dee4',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'f4a271780b3b488283632d22655bdc13',
#   'last_sample_token': '0434addced31451eac6a905767afbad8',
#   'name': 'scene-0125',
#   'description': 'Many parked cars, animal, many peds, wait at intersection'},
#  {'token': '00590cbfa24a430a8c274b51e1c71231',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': '1a229d68b67e467c8189c7bf492b5a2d',
#   'last_sample_token': '30fb9f4db67e4227bac0a672edf69ba1',
#   'name': 'scene-0126',
#   'description': 'Delayed left turn, jaywalker, parking lot, bus stops, parked bicycle, truck, turn right'},
#  {'token': '52b30ecd104a4f4eab6f8f5684a73e56',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': '0a2836bb3ae74d3b9b274fafc3c0cfd4',
#   'last_sample_token': '681b1333016445eaae5d5a3cb8eb245a',
#   'name': 'scene-0127',
#   'description': 'Enter car park, jaywalker, parked motorcycles, pass a bus'},
#  {'token': '5c9bd7ead37e4aa9989f7909f3a78baa',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': 'db46db0898a94f978cd567cbab5c7eb0',
#   'last_sample_token': 'b8125bcacf6d43768209b6db1dd3aac2',
#   'name': 'scene-0128',
#   'description': 'Parking lot, parked scooters, parked cars, ped, cross crosswalk, bump, parked bicycle'},
#  {'token': 'ef5f216134a94e308697ab4c75402a20',
#   'log_token': '34d0574ea8f340179c82162c6ac069bc',
#   'nbr_samples': 40,
#   'first_sample_token': '1f1afba5dd0d41dda5628e1df217e3c3',
#   'last_sample_token': '38cf5c35f1e34691b5776518701c4d80',
#   'name': 'scene-0129',
#   'description': 'Parking lot, cross crosswalk, go over bump, construction, peds, scooter on main road'},
#  {'token': 'dc6235e2281943548084c484cb38b876',
#   'log_token': '343d984344e440c7952d1e403b572b2a',
#   'nbr_samples': 40,
#   'first_sample_token': 'accbc57b8104487d9a56b3c671d1c166',
#   'last_sample_token': '4761ae96575544968b1312e32c5143e6',
#   'name': 'scene-0130',
#   'description': 'Peds crossing at crosswalk, drive along parked cars, ped, workers kneeling'},
#  {'token': '8857cf15fa7049a6b000490835d3b9fc',
#   'log_token': '343d984344e440c7952d1e403b572b2a',
#   'nbr_samples': 40,
#   'first_sample_token': '7db1dd74c9ba442caa316e383d0622b3',
#   'last_sample_token': '2457353f170345edacf29f6b75f3ba02',
#   'name': 'scene-0131',
#   'description': 'Parking lot, peds'},
#  {'token': '4f28b42169f4404cbab4b43476e13885',
#   'log_token': '343d984344e440c7952d1e403b572b2a',
#   'nbr_samples': 40,
#   'first_sample_token': '429fa8b5cc9b4eccb36d891cf9901830',
#   'last_sample_token': 'd33ad33a66b94f77af92075762ece116',
#   'name': 'scene-0132',
#   'description': 'Parked cars, turn left, parked bus'},
#  {'token': 'f57957ebc5654b649a0786d993b64be4',
#   'log_token': '343d984344e440c7952d1e403b572b2a',
#   'nbr_samples': 40,
#   'first_sample_token': '5843e9c7574c45188ce50c8b80dd1122',
#   'last_sample_token': '6661d00a00c34d20a01c7666290f3c56',
#   'name': 'scene-0133',
#   'description': 'Drive through parking lot, stopped bus, parked scooters, parked motorcycles, peds, parked trucks, approach barrier'},
#  {'token': 'd90b94e8bfd446cd9407f48665122268',
#   'log_token': '343d984344e440c7952d1e403b572b2a',
#   'nbr_samples': 40,
#   'first_sample_token': 'e410f12e40cd4483b919061fbd6084df',
#   'last_sample_token': 'e946d17c4e6d41d1a1b5779dbb0c472d',
#   'name': 'scene-0134',
#   'description': 'Approach intersection, fence, turn left, peds in sidewalk'},
#  {'token': '4db0eee3b82d49b198c1a411cf7f7d68',
#   'log_token': '343d984344e440c7952d1e403b572b2a',
#   'nbr_samples': 39,
#   'first_sample_token': '465ad1daf37546479028dcbfdbe31a60',
#   'last_sample_token': '85ae59e960574ac1bcc8df1f364835ba',
#   'name': 'scene-0135',
#   'description': 'Heavy traffic, sitting peds, parked motorcycles, 2 jaywalkers, turn right, busy intersection'},
#  {'token': '7365754410624f2f85087003f4ed41ad',
#   'log_token': '343d984344e440c7952d1e403b572b2a',
#   'nbr_samples': 40,
#   'first_sample_token': 'cb54b46ba586411da4ed583ad0bad9d4',
#   'last_sample_token': 'a0ec29607e5644a4abfaef970542e123',
#   'name': 'scene-0138',
#   'description': 'Bus stop, parked bicycles, bus stop, bicycle rack, peds'},
#  {'token': '01c8c59260db4a3682d7b4f8da65425e',
#   'log_token': '343d984344e440c7952d1e403b572b2a',
#   'nbr_samples': 40,
#   'first_sample_token': 'accc8d9fe7834602a03916890666df9f',
#   'last_sample_token': '57c08cd5247344e395c01c6784d90c6f',
#   'name': 'scene-0139',
#   'description': 'Ped standing, ped sitting, two parked motorcycles on road'},
#  {'token': '1fbcc26ebf6948bb964d3ae74939e8ea',
#   'log_token': 'da04ae0b72024818a6219d8dd138ea4b',
#   'nbr_samples': 40,
#   'first_sample_token': '7be8cbf65cfb4d4ea76d67b320e74662',
#   'last_sample_token': 'b8dabf85a8ed4f36bf90788eb7d3e774',
#   'name': 'scene-0149',
#   'description': 'Wait at intersection, turn left, bushes, bus stops, peds, parking lot'},
#  {'token': '94f224a2a36c4bbbab59120cc6c31f6e',
#   'log_token': 'da04ae0b72024818a6219d8dd138ea4b',
#   'nbr_samples': 39,
#   'first_sample_token': 'a3574e122ff5456580464138f4bd555c',
#   'last_sample_token': '5894f20b82764a20b76528bb15234f60',
#   'name': 'scene-0150',
#   'description': 'Oncoming scooter, scooters, busy intersection, walking peds'},
#  {'token': 'ba76f4185aa34ed3bff467ac640da902',
#   'log_token': 'da04ae0b72024818a6219d8dd138ea4b',
#   'nbr_samples': 40,
#   'first_sample_token': '090e988105f943718f7c8b823b49b44b',
#   'last_sample_token': '26dc352d775a4017a31a8f14d9b03474',
#   'name': 'scene-0151',
#   'description': 'Turn right, busy intersection, construction, peds, parked bicycles, construction vehicle, motorcycle'},
#  {'token': 'bd210a5bc7004d8c94b68cf6366612a2',
#   'log_token': 'da04ae0b72024818a6219d8dd138ea4b',
#   'nbr_samples': 39,
#   'first_sample_token': '38a589ffe74f42e19bb6075ea1e27c33',
#   'last_sample_token': '7534f0ab93144c6fa1d8b65887480b6c',
#   'name': 'scene-0152',
#   'description': 'Parked bicycles, bump, overtake parked buses, irregularly parked cars'},
#  {'token': '12cd5f88732749a58725528bb3d86958',
#   'log_token': 'da04ae0b72024818a6219d8dd138ea4b',
#   'nbr_samples': 39,
#   'first_sample_token': '49e7f76cbce44dd081a7ff79d063f298',
#   'last_sample_token': '38d6e984023148ca84fce609025c1dce',
#   'name': 'scene-0154',
#   'description': 'Turn left, peds at restaurant, parked bicycles, autonomous vehicle, parked vehicles, passing at narrow street, taxi, ped with bag, sitting ped'},
#  {'token': 'cd1a8954ff904333bb13fa1a6ee526fd',
#   'log_token': 'd0450edaed4a46f898403f45fa9e5f0d',
#   'nbr_samples': 39,
#   'first_sample_token': '13b3c19486a4446b9b33b7f83deb4aa1',
#   'last_sample_token': 'ee4f9a69b0df4fabbb48a8f0ae2da27e',
#   'name': 'scene-0155',
#   'description': 'Jaywalkers, turn left, stop for ped crossing, turn left, peds sitting in a restaurant'},
#  {'token': 'd0b2d916178a402a842c88f394d7d7e8',
#   'log_token': 'd0450edaed4a46f898403f45fa9e5f0d',
#   'nbr_samples': 40,
#   'first_sample_token': '37ca0461e1b04dc6b43278e827d117c0',
#   'last_sample_token': '96c34cc2e6ce49b5adcb9424cd9425a7',
#   'name': 'scene-0157',
#   'description': 'Passing scooter, wait at intersection, turn right'},
#  {'token': 'c0d3796765e2452d990309b2568adac5',
#   'log_token': 'd0450edaed4a46f898403f45fa9e5f0d',
#   'nbr_samples': 40,
#   'first_sample_token': 'b0935afc70df432897592ad1e510be40',
#   'last_sample_token': '64f955eb7d2c488ea9c8fefa747c8cd9',
#   'name': 'scene-0158',
#   'description': 'Worker stopped ego car, worker removes cones, follow truck, heavy traffic, construction, peds'},
#  {'token': '73d9a36f20594e658020ebfc5b0ba74a',
#   'log_token': 'd0450edaed4a46f898403f45fa9e5f0d',
#   'nbr_samples': 39,
#   'first_sample_token': 'e319b421809d48ea90b8b54ded10a082',
#   'last_sample_token': '331b9dc163364ae1baa63b989f99b08f',
#   'name': 'scene-0159',
#   'description': 'Peds crossing crosswalk, barrier being pushed across crosswalk, turn left, peds'},
#  {'token': '9eaabad9385b4fe1b9f397edead326ac',
#   'log_token': 'd0450edaed4a46f898403f45fa9e5f0d',
#   'nbr_samples': 40,
#   'first_sample_token': '122e8653d3924da0bc416e98bb9b7480',
#   'last_sample_token': 'b661753a96e948e89995a20a3b0da9db',
#   'name': 'scene-0160',
#   'description': 'Wait for oncoming car to pass, narrow road, parked cars'},
#  {'token': '0d2cc345342a460e94ff54748338ac22',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': 'f9878012c3f6412184c294c13ba4bac3',
#   'last_sample_token': 'a4ceea9b48de456e96bcc347c81c2338',
#   'name': 'scene-0161',
#   'description': 'Car overtaking, parking lot, peds, ped exiting car, objects on the ground'},
#  {'token': 'bc4fd5a05a004333b9411754630f4cba',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': 'c37e176850c9415ba36e9272d6b77d60',
#   'last_sample_token': 'b4aa8a06cac446e493e74c364f19d1d2',
#   'name': 'scene-0162',
#   'description': 'Leaving parking lot, parked cars, hidden ped'},
#  {'token': '6ab3d1e9476d4cd89d4949d69d056901',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': '1531d32d9b5a4da6a20917ac6bd5c8a9',
#   'last_sample_token': '47503661da7b4ed5a65997cb4681986f',
#   'name': 'scene-0163',
#   'description': 'Drive along street with dozens of parked cars, bicycle rack'},
#  {'token': '75a4ec12042542149b0a77a0a10d6330',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 39,
#   'first_sample_token': '9dafa2548c884e5884e9cedd626ee62d',
#   'last_sample_token': '7dfaa40ce3aa45078588becf7ab079d4',
#   'name': 'scene-0164',
#   'description': 'Turn into narrow street, parked cars, parked motorcycles'},
#  {'token': '8fbbe701baf641359129ea166e1674ec',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': '2acc9fb43d5941d7bdd81c7d62834a6f',
#   'last_sample_token': '3b58e08f5ed24f51904b0d8b28dcd553',
#   'name': 'scene-0165',
#   'description': 'Pass crane, truck and construction workers, long loaded truck'},
#  {'token': '15e1fa06e30e438a98430cc1fd0e8a69',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 39,
#   'first_sample_token': '99aa50461c1a4adba4cf26159f72777e',
#   'last_sample_token': 'ba46ef41a8c644e49c2ea8018087c8ef',
#   'name': 'scene-0166',
#   'description': 'Leaving narrow street, many cars'},
#  {'token': '448cf480b0b8400a86881d28c2c5f734',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': '3904fb3c210b46d18016a3beb1be63d6',
#   'last_sample_token': '42093b3bda894f67a2d77e49eb243f43',
#   'name': 'scene-0167',
#   'description': 'Pass parked trucks, sitting pedestrians, turn right'},
#  {'token': 'bef135921f374f838bf0badae55cac83',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': '88f40191f4c5462c90e26fe3f64ee933',
#   'last_sample_token': '8e36fb3f1bfa4cd396761d58e399922c',
#   'name': 'scene-0168',
#   'description': 'Parking lot, peds, parked cars, parked scooters, eletronic display'},
#  {'token': 'ab6eea0e06c84f70be411a9d36636a7a',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': '45e59d8fd96543c8af0b9c566b0f5159',
#   'last_sample_token': '8f42e8259d32439981c6a17f934c5de0',
#   'name': 'scene-0170',
#   'description': 'Turn left, truck parked in the middle of the street, ego vehicle coming to full stand'},
#  {'token': '2ffd7e2a1daf4b928464ddb2ed3dca59',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': '917aab7e32f94412b9dca17a5607db12',
#   'last_sample_token': 'f1e0317b4963452e9cbd3aaa7ebe7579',
#   'name': 'scene-0171',
#   'description': 'Densely parked trucks'},
#  {'token': '634a8c5835e44aec912604a9a1972a5d',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': 'c29f3669ab774a8296aba6d57427379a',
#   'last_sample_token': 'e304aa1c0cd643af977edfde5a5267d2',
#   'name': 'scene-0172',
#   'description': 'Bus indicates turn but does not go, overtake bus'},
#  {'token': '8931a57994764c9b945a7a1b352c9ae5',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': '12bb466d25b242e5b3fdcbdd8f5c9919',
#   'last_sample_token': '76d74dfee6eb41e68388c823edf26fe6',
#   'name': 'scene-0173',
#   'description': 'Drive along road barriers'},
#  {'token': 'fd5a3c6d3ad44954a8045edbe9d93763',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': '68d55043775840cbacb2d9d2bf15ad4a',
#   'last_sample_token': '7970ca79ac284dbc94edb0bbae3faff6',
#   'name': 'scene-0174',
#   'description': 'Reflections, parked cars, trucks'},
#  {'token': '7cf32f906f50415786414ce8bbe10e9b',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 40,
#   'first_sample_token': 'a3de7edc77e240d68bb46d2c169075f1',
#   'last_sample_token': 'cec12b1fd11d4a1fba49bb926d527757',
#   'name': 'scene-0175',
#   'description': 'Truck, parked vehicles, bicycle, special trailer, parked car, parked bicycle'},
#  {'token': 'c7492bdc08f8450fa580b7787331f0c9',
#   'log_token': 'b05f285d53744542a3413476d6dd9270',
#   'nbr_samples': 39,
#   'first_sample_token': '9fa08d55fc6e413f8a3fffb0e32849a6',
#   'last_sample_token': 'bcfe4c33810c496f9a9674a869c8f101',
#   'name': 'scene-0176',
#   'description': 'Parked cars, extra-long bendy bus, banners, arrive at intersection, turn right, truck'},
#  {'token': 'fcb40dc8514444c49b1fdc06f80a123b',
#   'log_token': '6f5b61bfb298454eb6fe7ba279792815',
#   'nbr_samples': 40,
#   'first_sample_token': '3b477456ee2e4f7da377b13cde7c48c1',
#   'last_sample_token': '0c362e51c56c4e8d99314803b27eee9e',
#   'name': 'scene-0177',
#   'description': 'Parking toll gate'},
#  {'token': 'f4395dd8e4004f12a8dec3079a93d804',
#   'log_token': '6f5b61bfb298454eb6fe7ba279792815',
#   'nbr_samples': 39,
#   'first_sample_token': 'b6de1b257925456aba659f3873944b9a',
#   'last_sample_token': '1e72d3e64b394b33b66ec0b895323ac5',
#   'name': 'scene-0178',
#   'description': 'Parking lot, parked motorcycles, turn right, jaywalker'},
#  {'token': '2538a745a83f430eb590d48b4743e179',
#   'log_token': '6f5b61bfb298454eb6fe7ba279792815',
#   'nbr_samples': 40,
# ...
#   'name': 'scene-1063',
#   'description': 'Night, bump, ped, difficult lighting, trash bins, residential area'},
#  {'token': 'f97bf749746c4c3a8ad9f1c11eab6444',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': 'b62a484b94a04ae4b1b2729fb2064696',
#   'last_sample_token': '9435f31153e845c59b8481126eadc094',
#   'name': 'scene-1064',
#   'description': 'Night, trash cans, wait for scooter, turn right, parking lot'},
#  {'token': 'bd338b912ce9434995b29b6dac9fbf1d',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': 'dc2def2a7bc94693b67eba2ffbe13a56',
#   'last_sample_token': '0888060b915444b592ab9ae2527b9d80',
#   'name': 'scene-1065',
#   'description': 'Rain, Night, bump, motorcycle, difficult lighting, overtake parked car'},
#  {'token': 'afbc2583cc324938b2e8931d42c83e6b',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': '21bb21c84c3e43908cd554db2686278f',
#   'last_sample_token': '887e6f18b1b341d9b55bc4289c2e0388',
#   'name': 'scene-1066',
#   'description': 'Night, bump, scooter, difficult lighting'},
#  {'token': '16be583c31a2403caa6c158bb55ae616',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': 'b6a9d120895e4207a0527ad4b3284d42',
#   'last_sample_token': 'ff729b4a16a74350a0faa2b094ebfb2a',
#   'name': 'scene-1067',
#   'description': 'Night, rain, bump, ped in dark, arrive at intersection'},
#  {'token': 'e8834785d9ff4783a5950281a4579943',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': '2920a3315ccd4fefb30fb0468ebb2351',
#   'last_sample_token': 'f22f8f2fc7314b028419d8332c03a049',
#   'name': 'scene-1068',
#   'description': 'Night, wait at intersection, motorcycle, turn left'},
#  {'token': 'd29527ec841045d18d04a933e7a0afd2',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': 'b58985f7ddc2454d95cb84a65d1fe9fe',
#   'last_sample_token': '5ba9f3b30a5d42aeb790bfca7648bf77',
#   'name': 'scene-1069',
#   'description': 'Night, truck, congestion, parked bicycle'},
#  {'token': '85889db3628342a482c5c0255e5347e9',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 41,
#   'first_sample_token': '23779301ebc34c1284e539ddf057f0b4',
#   'last_sample_token': '1be89dec99ca4b3d8bad9acf8a7edfa5',
#   'name': 'scene-1070',
#   'description': 'Night, congestion, peds, motorcycle'},
#  {'token': '0dae482684ce4cd69a7258f55bc98d73',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': '7e351605549547f8af19432917f23b73',
#   'last_sample_token': '58ac8c22238e43efa70279ddaba46180',
#   'name': 'scene-1071',
#   'description': 'Night, scooters, peds, parked bicycle, bus stop, cross intersection,  ped with bag near road'},
#  {'token': '82cabcf15a1a48aca6bbf082f8710e39',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': 'f9ad282e31ce47d5a16dffc3b25c456a',
#   'last_sample_token': '7d9d76585f0d4af98e44a09f71ca6c0a',
#   'name': 'scene-1072',
#   'description': 'Night, bus stop, scooter, trash can pushable / pullables, residential'},
#  {'token': '6498fce2f38645fc9bf9d4464b159230',
#   'log_token': 'e55205b1f2894b49957905d7ddfdb96d',
#   'nbr_samples': 40,
#   'first_sample_token': '127c5ddf95e947ef96888e56d5a355f6',
#   'last_sample_token': 'f0ee73d43c2748fbb584d1a062e2773a',
#   'name': 'scene-1073',
#   'description': 'Night, scooters, turn left, dense traffic'},
#  {'token': '865c607c8ef44f13b39744a0de110740',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '18a4f9b1932040458599a7d5fdcf193e',
#   'last_sample_token': 'cca9e35c3b7f48d88ed94470c47c3066',
#   'name': 'scene-1074',
#   'description': 'Night, rain, high speed, bus stop, bus, peds, parked bicycle'},
#  {'token': '277af8c7487f4f24bd2953d4dc8d11ff',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '8f11300c2f5d47aca83db71bb7f28412',
#   'last_sample_token': '682680a256b140029b1ade1ca9bb79ff',
#   'name': 'scene-1075',
#   'description': 'Night, bus, parked cars, bus stop, peds, trash cans, high speed'},
#  {'token': '7061c4fa99a44d02af4a3e2689be4457',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': '372af1737a354eeaacf026f684f2a57c',
#   'last_sample_token': 'b06ac583f2394428b4333abac695ff04',
#   'name': 'scene-1076',
#   'description': 'Night, trash cans, scooter, ped, turn left'},
#  {'token': 'd25718445d89453381c659b9c8734939',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': '5998b71b64c146769bde1d5430741381',
#   'last_sample_token': 'ee9b3f38dadd40588f43ba590c4751b9',
#   'name': 'scene-1077',
#   'description': 'Night, big street, bus stop, high speed, construction vehicle'},
#  {'token': 'c949ec2cca7047bdb67dce64b6c3586a',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'e54a957358954c2fbec96cd497f19e0b',
#   'last_sample_token': '4a8bcdad197b4c879a1835e320749e67',
#   'name': 'scene-1078',
#   'description': 'Night, big street, high speed, scooters, bus, lane change'},
#  {'token': 'f98a50e675b14266a6c53cb25a0351fa',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '8d8d57bc81ac451890f5816c6b522ce9',
#   'last_sample_token': '7547902b24184045acb1ac3f52847939',
#   'name': 'scene-1079',
#   'description': 'Night, big street, high speed, arrive at intersection'},
#  {'token': 'a1e7cd557b9541dbb00822ea0c56204b',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'a049a8d809074244ba843729972a0da2',
#   'last_sample_token': '2ac15ff8d48043b1aff9fe6ed18ce50a',
#   'name': 'scene-1080',
#   'description': 'Night, big street, dense traffic, scooters'},
#  {'token': '26c089d84086473e87607ae5c6ae85c6',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '6bcee0dba9dc4147869c586e35fa4e2f',
#   'last_sample_token': '8a1b6cb9a00f496787145ce8b1f41c5b',
#   'name': 'scene-1081',
#   'description': 'Night, rain, big street, congestion, cars, scooter, arrive at intersection'},
#  {'token': '400b708de5d7434d8964da4a0246d164',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'e987093d34c74e24a5196dc0f7ea3d6d',
#   'last_sample_token': '0f08d75bbd8a4388bad0fc270c2aa1e2',
#   'name': 'scene-1082',
#   'description': 'Night, big street, wait at intersection'},
#  {'token': '567fcd99d0dc4fa088f52b047f4ebdcf',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'ad6e29f44fda4af9baa5538e32d92e55',
#   'last_sample_token': '7b9e7c32baac4276ba7ba83252e672a3',
#   'name': 'scene-1083',
#   'description': 'Night, big street, bus, scooter, turn right'},
#  {'token': 'affb0caa5d2948f98cee5c42c7aefc1c',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': 'e2697d1b92664613a8e6ffb7bbeba167',
#   'last_sample_token': '01a8dff30c024b8ab12cab6077b5302c',
#   'name': 'scene-1084',
#   'description': 'Night, scooter, peds, bus stop, parked cars, wait'},
#  {'token': '8d267899e2e843d4905fafd1f12c0a20',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': '84eb336ce2dc4332aa7e966d1a751b7a',
#   'last_sample_token': 'cf95d5345e944a9ebd703a788563f068',
#   'name': 'scene-1085',
#   'description': 'Night, many peds, parked bicycles, turn left, parked scooters, congestion, peds with bags, cars in parking garage on second floor, trash cans'},
#  {'token': '1b5ef5ecb2084b89aa0314d65f25d9e1',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '6522941a2ee34a95acf08c4d3578e4c8',
#   'last_sample_token': '193d4003e9194f3c98e6112ca2f4d9c1',
#   'name': 'scene-1086',
#   'description': 'Night, bumps, parked car, peds, trash cans'},
#  {'token': 'f143809fc26c4bb296f4f367b0954c26',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'd3c2b0a3d30145159453681bc6b5b4e5',
#   'last_sample_token': '086c1d574061457fb287ca8a0ee4a16c',
#   'name': 'scene-1087',
#   'description': 'Night, residential area, low traffic, turn right, bump, ped in dark, parked bicycle'},
#  {'token': 'fe4fdd7a28754baeac7074ad78f55a52',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'e2e7ed5a54504450be4270010c0f8098',
#   'last_sample_token': 'd3f0e2be2cfc4a9ebf6e28a08d3ebab2',
#   'name': 'scene-1088',
#   'description': 'Night, peds, trash cans, ped walking dog, turn right, parked car'},
#  {'token': '980ddcb62e294608bd4235b0dfd517f4',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'f3fd1c5a111d4ac58d26ad6a577b736f',
#   'last_sample_token': '0e0397cef54a495e8919d0b3c4202de3',
#   'name': 'scene-1089',
#   'description': 'Night, turn left, bump, trash cans, turn left, ped in dark'},
#  {'token': '6d8cb5391245464c9de1c412819df210',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '2aeeb7ac5f244406b8017d1e7b795df8',
#   'last_sample_token': 'c1a1f32e00494e1cb589f02e0561bea9',
#   'name': 'scene-1090',
#   'description': 'Night, trash cans, parked car, ped in dark, reflections in water'},
#  {'token': '24d0c3ea8a2049468201c055667d6bc3',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': '350222ca342b46c195ff574af999bd0a',
#   'last_sample_token': '3018c0295fb7498baf1bed6096f8ae13',
#   'name': 'scene-1091',
#   'description': 'Night, parked cars, peds, turn right, dog, jaywalkers, trash bins'},
#  {'token': 'd2db9f5df62c4d338d3bed43f616b954',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': 'c690e424602a4de5afdb2f5194b7fc59',
#   'last_sample_token': 'e386ce38d87e4e699b13f618af167829',
#   'name': 'scene-1092',
#   'description': 'Night, many peds, many trash cans, ped with bag, stopped taxi, delivery scooter, arrive at intersection'},
#  {'token': '1be49200788d4e38ae4496b27b233ccb',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': '19cfb9dfc26947fcbde40c066bb7ad8c',
#   'last_sample_token': '6d7574d3ac054776b67fdc05a5ddb38d',
#   'name': 'scene-1093',
#   'description': 'Night, wait at intersection, peds crossing crosswalk, peds sidewalk, personal mobility device'},
#  {'token': 'de7d80a1f5fb4c3e82ce8a4f213b450a',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'e6b0b282aa174a978272dc2d0a89d560',
#   'last_sample_token': '4e1d1031fe9f45f981a2f598365fc645',
#   'name': 'scene-1094',
#   'description': 'Night, after rain, many peds, PMD, ped with bag, jaywalker, truck, scooter'},
#  {'token': 'a2b64d02c5fa4b9bab671a97561b6b33',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '344e3d96df1d44dfb8fe0ee4d69b980b',
#   'last_sample_token': 'f7774606bec7410089d84d80f97b6bf6',
#   'name': 'scene-1095',
#   'description': 'Night, rain, lane change, cross intersection, scooter, bus, arrive at intersection'},
#  {'token': '9771da5dd7bb4657be34365619e39dab',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': '474423dd45954adbbbf696287ae96225',
#   'last_sample_token': '33ebeee68d1948d0851f465e8568e174',
#   'name': 'scene-1096',
#   'description': 'Night, wait at intersection, peds crossing crosswalk, scooter'},
#  {'token': '3ace9decdd1f4ea0915b9862c95ca128',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '15ddb219df5e44ff97b2f56dfe43f175',
#   'last_sample_token': 'b6caf1f9962f4495872cc5c815b94fc3',
#   'name': 'scene-1097',
#   'description': 'Night, scooter, start at intersection, turn right, ped crossing crosswalk, bus'},
#  {'token': 'cdeb0e85e43e481a87b2251351e10c2f',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'bf70c75762b0498b89f8f5add90726fa',
#   'last_sample_token': '0a95f81333cb4aaf86fb63df52504845',
#   'name': 'scene-1098',
#   'description': 'Night, peds, scooter, bus, waiting at intersection'},
#  {'token': 'b57e1a48e584451f8f966ab083c8d07d',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '7e85de15de2544ff8c2d975acbfc1e5d',
#   'last_sample_token': 'd47623a57d094abc9e63f44508299c03',
#   'name': 'scene-1099',
#   'description': 'Night, wait at busy intersection, peds, scooter on sidewalk, attempt to turn right'},
#  {'token': 'e233467e827140efa4b42d2b4c435855',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'a480496a5988410fbe3d8ed6c84da996',
#   'last_sample_token': 'abf3d91d3c28407e80e3334fe89c03cb',
#   'name': 'scene-1100',
#   'description': 'Night, peds in sidewalk, peds cross crosswalk, scooter, PMD, difficult lighting'},
#  {'token': 'cfa36eca40364e5bb15f550a077a21c5',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '8ac6c53be5e4438aacc163a391e0d963',
#   'last_sample_token': '340c6ba976c94c3fb3961ad9bf6d420b',
#   'name': 'scene-1101',
#   'description': 'Night, buses, peds, rain, right turn'},
#  {'token': '04e5f089805540a5a9e73c1b7c54ee8c',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': '3b12e85035b54df1a00a596e48efb661',
#   'last_sample_token': '229f774ed3094b2bb23c32c435b8499c',
#   'name': 'scene-1102',
#   'description': 'Night, rain, scooter, cars, high speed, cross intersection, arrive at intersection'},
#  {'token': 'e3b6fe9201c64334be311d4249a0c80e',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 41,
#   'first_sample_token': 'b1a4ac5193024c4d90b0b5b55bc127fb',
#   'last_sample_token': 'fd01fd487ac34d99bd030c6dd55b200d',
#   'name': 'scene-1104',
#   'description': 'Night, truck, rain, cross intersection'},
#  {'token': '692fe09aecae4b1a94f8a3bceedd9b7c',
#   'log_token': '8fefc430cbfa4c2191978c0df302eb98',
#   'nbr_samples': 40,
#   'first_sample_token': 'a7a2c378191b4c4c9abdac947d163e5f',
#   'last_sample_token': '1c640fed08564c4881e583e0498b496b',
#   'name': 'scene-1105',
#   'description': 'Night, ped, avoid parked car, parked cars'},
#  {'token': 'e5514b8f435e475cac4eba74b44773b5',
#   'log_token': 'f93e8d66ce4b4fbea7062d19b1fe29fb',
#   'nbr_samples': 40,
#   'first_sample_token': '178263c0453842c3b66e47b6bc5685f6',
#   'last_sample_token': 'f1b932b0d0804f02bea440d72047febd',
#   'name': 'scene-1106',
#   'description': 'Night, rain, high speed, scooter, bus stop, low traffic, bus'},
#  {'token': '89f20737ec344aa48b543a9e005a38ca',
#   'log_token': 'f93e8d66ce4b4fbea7062d19b1fe29fb',
#   'nbr_samples': 41,
#   'first_sample_token': 'f5eefd9b8f024c299253db54fb0677f4',
#   'last_sample_token': 'a8a6bf5c96d147fcbf49633e0cce7fe7',
#   'name': 'scene-1107',
#   'description': 'Night, rain, high speed, scooter, dense traffic at other lane'},
#  {'token': 'd3c39710e9da42f48b605824ce2a1927',
#   'log_token': 'f93e8d66ce4b4fbea7062d19b1fe29fb',
#   'nbr_samples': 40,
#   'first_sample_token': '032133a8a45143ab958d6db35f91381e',
#   'last_sample_token': 'b2af46f0857043b0896fc842f20cd1da',
#   'name': 'scene-1108',
#   'description': 'Night, wet front camera, rain, bus, wait at intersection, scooters'},
#  {'token': '7ed1b613f0ee47ceaf6d19ca3947f825',
#   'log_token': 'f93e8d66ce4b4fbea7062d19b1fe29fb',
#   'nbr_samples': 39,
#   'first_sample_token': 'c4048cf79e5c4b88a5845dfc98b3b1e9',
#   'last_sample_token': 'd501737a45d146f8af94511adaf27761',
#   'name': 'scene-1109',
#   'description': 'Night, rain, bus, lightning'},
#  {'token': '57146b2ebf10432f84b15a3038fe1755',
#   'log_token': 'f93e8d66ce4b4fbea7062d19b1fe29fb',
#   'nbr_samples': 40,
#   'first_sample_token': 'be75cf94ec3841cca384e1c9a2499a00',
#   'last_sample_token': '5abb17189643497f8600a187fb20aa55',
#   'name': 'scene-1110',
#   'description': 'Night, rain, bus, turn right, peds, bus stop'}]

# %%
def find_scenes_by_desc(keywords):
    return [ (i['name'], i['description']) for i in nusc.scene if any(k in i['description'].lower() for k in keywords) ]

def find_scenes_by_name(name):
    return [ (i['name'], i['description']) for i in nusc.scene if name in i['name'].lower() ]

# %%
len(find_scenes_by_desc(['roundabout']))
# Out:
# 12

# %%
len(find_scenes_by_desc(['lane change', 'change lane']))
# Out:
# 18

# %%
len(find_scenes_by_desc(['u-turn', 'uturn', 'u turn']))
# Out:
# 2

# %%
len(find_scenes_by_desc(['merge', 'merging']))
# Out:
# 1

# %%
print(len(find_scenes_by_desc(['parking'])))
(find_scenes_by_desc(['parking']))
# Out:
# [('scene-0002',
#   'Intersection, peds, waiting vehicle, parked motorcycle at parking lot'),
#  ('scene-0003', 'Parking lot, barrier, exit parking lot'),
#  ('scene-0021',
#   'Wait at intersection, jaywalkers, parking lot, parked bicycle, turn right, construction, truck'),
#  ('scene-0035',
#   'Parking lots, trash can, bump, scooter, peds, potential jaywalkers, bus stop, oncoming bus'),
#  ('scene-0039',
#   'Busy street, parked cars, parking lot, ped sitting at bus stop, motorcycle driving'),
#  ('scene-0042',
#   'Parked cars, many peds, parked bicycles, trash can, parking lots'),
#  ('scene-0045', 'Full parking lot, peds, exiting from car park'),
#  ('scene-0063',
#   'Exit passage, parking lot, flag, trucks, wait at intersection'),
#  ('scene-0064', 'Parking lots, oncoming special electrical vehicle'),
#  ('scene-0065', 'Wait at intersection, truck, peds, turn right, parking lot'),
#  ('scene-0066',
#   'Parking lots, parked truck, construction, congestion, worker directing traffic, passing cars'),
#  ('scene-0067',
#   'Exit construction, ped on crosswalk, construction workers, parking lot'),
#  ('scene-0070',
#   'Peds, ped with bag, bus stop, parking lot, turn right, follow cyclist, trailers, turn left'),
#  ('scene-0093', 'Turn right, parking lots, cross intersection'),
#  ('scene-0105',
#   'Parking lots, peds, parked cars, cars on elevated bridge, truck'),
#  ('scene-0120',
#   'Parked motorcycles, parking lot, wait at intersection, truck, ped very close to ego-vehicle'),
#  ('scene-0126',
#   'Delayed left turn, jaywalker, parking lot, bus stops, parked bicycle, truck, turn right'),
#  ('scene-0128',
#   'Parking lot, parked scooters, parked cars, ped, cross crosswalk, bump, parked bicycle'),
#  ('scene-0129',
#   'Parking lot, cross crosswalk, go over bump, construction, peds, scooter on main road'),
#  ('scene-0131', 'Parking lot, peds'),
#  ('scene-0133',
#   'Drive through parking lot, stopped bus, parked scooters, parked motorcycles, peds, parked trucks, approach barrier'),
#  ('scene-0149',
#   'Wait at intersection, turn left, bushes, bus stops, peds, parking lot'),
#  ('scene-0161',
#   'Car overtaking, parking lot, peds, ped exiting car, objects on the ground'),
#  ('scene-0162', 'Leaving parking lot, parked cars, hidden ped'),
#  ('scene-0168',
#   'Parking lot, peds, parked cars, parked scooters, eletronic display'),
#  ('scene-0177', 'Parking toll gate'),
#  ('scene-0178', 'Parking lot, parked motorcycles, turn right, jaywalker'),
#  ('scene-0179', 'Ped walking to the ego car, parked truck ahead, parking lot'),
#  ('scene-0180', 'Parking lot with lots of parked cars'),
#  ('scene-0182', 'Peds, bus stop, taxi, narrow road, parking lot, slope'),
#  ('scene-0183', 'Parked motorcycle, bike, parking driveway, parked cars'),
#  ('scene-0185',
#   'Parking bay, peds, ped hesitates to cross, ego car stops, ped crossing'),
#  ('scene-0191', 'Turn left, parking lot'),
#  ('scene-0193', 'Vegetation, parking lot, turning cars'),
#  ('scene-0200', 'Parked cars, parking lot'),
#  ('scene-0203',
#   'Construction, bus, turn right, crane, parked cars, ped crossing crosswalk, ped with backpack, parking lot'),
#  ('scene-0210',
#   'Parked vehicles, construction vehicle, container, peds, excavator, cranes, parking lot, turn left, worker sitting on trunk of pickup truck'),
#  ('scene-0218', 'Parking lot, walking peds, close-up peds, not moving'),
#  ('scene-0220', 'Parking lot, parked bikes in bike rack, peds'),
#  ('scene-0225',
#   'Wait at intersection, construction, peds crossing crosswalk, turn right, parking lot'),
#  ('scene-0254',
#   'Parked cars, long corridor, parking lot, flag, arrive at intersection'),
#  ('scene-0255', 'Parking lot, turn left'),
#  ('scene-0283',
#   'Parking lot, right turn, approach policeman handling traffic'),
#  ('scene-0284',
#   'Police lets us pass, left turn, ped stand beside the parked car, parking lot'),
#  ('scene-0287',
#   'Overtake heavy truck, stopped motorcycle, parking lot, peds, arrive at intersection'),
#  ('scene-0302', 'Huge parking lot, dense traffic'),
#  ('scene-0359',
#   'Bus stop, parked bicycle, sparsely populated with peds, parking lot'),
#  ('scene-0360',
#   'Parking lot, worker cleaning, garbage, traffic cones, knocked over traffic cone'),
#  ('scene-0361', 'Parking lot, turn left, cone'),
#  ('scene-0362', 'Ped, parking lot, parked scooter, turn left'),
#  ('scene-0373',
#   'Parking lot, peds, construction, a car doing reverse parking'),
#  ('scene-0374', 'Parking lot, vehicle reverses into parking spot'),
#  ('scene-0375', 'Parking lot, turn right, peds'),
#  ('scene-0376', 'Parking lot, peds, oncoming scooter'),
#  ('scene-0382', 'Turn left, parking lot, peds, parked motorcycles'),
#  ('scene-0395',
#   'Ped walking dog, peds, parking lot, truck, parked motorcycle'),
#  ('scene-0396', 'Parked cars, parking lot, peds'),
#  ('scene-0420',
#   'Exit parking lot, turn left, peds, parked bicycle, arrive at intersection'),
#  ('scene-0423', 'Many peds, peds walking in street, turn left, parking lot'),
#  ('scene-0426', 'Bus, unloading van, peds, parking lot, parked bicycles'),
#  ('scene-0427', 'Parking lot, many peds, bump, buses, congestion'),
#  ('scene-0429',
#   'Half-open parking garage, parked scooters, oncoming scooter, parked car, peds, barricade'),
#  ('scene-0432',
#   'Nature, parking bay, bus stop, many peds, oncoming scooter, bump'),
#  ('scene-0435',
#   'Unusual buildings, slope, turn right, peds, parking lot, parked cars'),
#  ('scene-0439', 'Parking lot, peds, parked bicycle'),
#  ('scene-0440', 'Rain, small crane, parking lot'),
#  ('scene-0441', 'Rain, cross intersection, lane change, parking lot'),
#  ('scene-0443', 'Rain, crane, parking lot, overtake stopped vehicle, ped'),
#  ('scene-0444', 'Rain, parked vehicles, parking lot, bendy bus'),
#  ('scene-0445', 'Rain, parking lot'),
#  ('scene-0447', 'Rain, parking lot, turn left'),
#  ('scene-0449', 'Rain, parking lot, turn left, barriers, traffic cones'),
#  ('scene-0450', 'Rain, parking lot, many trucks, peds'),
#  ('scene-0454', 'Rain, turn left, bike rack, parking lot'),
#  ('scene-0455',
#   'Rain, bus, jaywalker, parking lot, parked bicycle, peds, bicycle rack'),
#  ('scene-0456', 'Rain, parking lot, bicycle rack, turn right, crane'),
#  ('scene-0457', 'Rain, turn right, parking lot, wait at intersection'),
#  ('scene-0459', 'Rain, parking lot, crane'),
#  ('scene-0462', 'Rain, cross intersection, parking lot, construction vehicle'),
#  ('scene-0480', 'Rain, parked cars, bicycle, parking lot'),
#  ('scene-0499', 'Construction zone, workers, parking lot, park motorcycle'),
#  ('scene-0500',
#   'Left turn, large truck turns right, parked vehicles, parking lot, peds'),
#  ('scene-0510',
#   'Turn left, parking lot, bicycle rack, ped, parked bicycles, pedestrians'),
#  ('scene-0511',
#   'Car attempting to park, peds, parked motorcycle, parked bicycles, parking lot, ped picking up object on road, parked scooter, parked trucks, bicycle rack'),
#  ('scene-0512',
#   'Right bend, parked motorcyle, parked bicycles, parked truck, parking lot'),
#  ('scene-0514', 'Waiting to turn left, oncoming traffic, parking lot, peds'),
#  ('scene-0515', 'Parking lot, construction zone'),
#  ('scene-0517',
#   'Construction zone, constructing vehicles, pedestrian, parking lot'),
#  ('scene-0518',
#   'Parking lot, peds, parked motorcyle, bicycle racks, oncoming traffic, turn left, car exiting parking lot, car being unloaded'),
#  ('scene-0521', 'Parking lot, ped, parked bicycle, peds crossing crosswalk'),
#  ('scene-0524', 'Parking lot, parked truck, pedestrian, oncoming truck'),
#  ('scene-0525', 'Turn right, parking lot, peds waiting, parked cars'),
#  ('scene-0526', 'Parking lot, wide biaising for parked cars, pedestrian'),
#  ('scene-0527',
#   'Parking lot, lorry containers, pedestrian and dog, large truck'),
#  ('scene-0529', 'Parked cars, parking lot'),
#  ('scene-0530', 'Parked cars, parking lot, container, stop at intersection'),
#  ('scene-0531',
#   'Turn right, oncoming traffic, parking lot parked trucks, containers'),
#  ('scene-0538',
#   'Ton of pedestrians in park, parking lot, parked motorcycles, parked bicycles, jaywalkers'),
#  ('scene-0543',
#   'Oncoming truck, pedestrian, parking lot, parked cars by the side'),
#  ('scene-0552',
#   'Bendy bus, school bus, parking lot, turn left, parked bus, overtake truck'),
#  ('scene-0561',
#   'Wait at intersection, turning left, cars turning together, parking lot'),
#  ('scene-0577',
#   'Rain, turn right, bicycle rack, cross intersection, parking lot'),
#  ('scene-0583', 'Rain, parking lot, stopped briefly at intersection'),
#  ('scene-0584', 'Rain, turn right, exiting car, parking lot'),
#  ('scene-0588', 'Rain, turn right, parking lot'),
#  ('scene-0600', 'Rain, parked busses, parking lot'),
#  ('scene-0630',
#   'Rain, construction, fence, special construction vehicle, nature, crane, wait at intersection, parking lot, cross intersection'),
#  ('scene-0633', 'Rain, industrial, parked trucks at parking lot'),
#  ('scene-0634', 'Rain, industrial, parking lot, semi backing up'),
#  ('scene-0644',
#   'Rain, parked cars, parking lot, ped, parked truck, construction vehicle, sign trailer'),
#  ('scene-0646', 'Heavy, parking lot, truck, concrete barricades'),
#  ('scene-0650', 'Rain, reflections, parking lot, arrive at intersection'),
#  ('scene-0655',
#   'Parking lot, parked cars, jaywalker, bendy bus, gardening vehicles'),
#  ('scene-0656', 'Parked cars, jaywalker, parked bicycle, parking lot'),
#  ('scene-0657', 'Parking lot, turn left, heavy truck'),
#  ('scene-0659', 'Peds, parking lot, large truck, scooter'),
#  ('scene-0665',
#   'Sitting ped, parking lot, turn left, wait at intersection, police car, turn left'),
#  ('scene-0666', 'Parking lot, jaywalker'),
#  ('scene-0669',
#   'Turn right, dense traffic, ped sitting at bus stop, parking lot'),
#  ('scene-0697',
#   'Ped crossing road, parked cars, ped on sidewalk, pole, bench, trailer, cross intersection, parked bus, parking lot'),
#  ('scene-0698',
#   'Pullable object, peds on sidewalk, parked cars, parking lot, truck, arrive at intersection, cone'),
#  ('scene-0700',
#   'Overtake stopped cars, arrive at intersection, car overtaking us, barriers, turn right, stopped cars at red light, ped on sidewalk, parking lot, bus stop'),
#  ('scene-0701',
#   'Parked cars, ped on sidewalk, bicycle, car overtaking us, ped on sidewalk, parking lot, arrive at intersection, wait at intersection'),
#  ('scene-0703',
#   'Wait at intersection, cars, parking lot, cars overtaking us, cone, cross intersection'),
#  ('scene-0704',
#   'Cars, bicycles, peds on sidewalk, parking lot, arrive at intersection, wait at intersection, truck, motorcycle'),
#  ('scene-0735',
#   'Cross intersection, flags, stopped bus, parked vehicles, peds, bicycle rack, parking lot, cross intersection, parked bicycle'),
#  ('scene-0738',
#   'Trailers, peds on sidewalk, barrier, trucks, bendy bus, cross roundabout, cones, parking lots, cross intersection, bicycle'),
#  ('scene-0739',
#   'Parking lot, peds, child standing in vehicle, reach intersection, truck'),
#  ('scene-0740', 'Turn right, parking lot, parked cars, dense traffic'),
#  ('scene-0741', 'Parked cars, parking lot, peds on side walk'),
#  ('scene-0744',
#   'Parked cars, parking lot, change lane and change back, arrives at intersection'),
#  ('scene-0746',
#   'Parked cars, parking lot, parked trucks, container, peds, arrive at intersection, wait at intersection'),
#  ('scene-0747', 'Wait at intersection, peds crossing crosswalk, parking lot'),
#  ('scene-0750',
#   'Wait at intersection, parking lot, traffic chaos, truck blocking us, cross busy intersection, cyclist, parked cars'),
#  ('scene-0751',
#   'Parking lot, bicycle, ped entering car, construction vehicles, parked cars'),
#  ('scene-0761', 'Construction vehicle, peds, animal, parking lot'),
#  ('scene-0762',
#   'Parking lot, many peds, container, turn right, parked scooters, parked bicycle, bicycle rack'),
#  ('scene-0763',
#   'Fence, parking lot, bicyclist, buses, parked cars, ped with pets'),
#  ('scene-0764',
#   'Bicycle, parked cars, parked trucks, follow bicycle, construction vehicle, ped, animal, containers, parking lot'),
#  ('scene-0765',
#   'Wait at intersection, parking lot, low traffic, truck, motorcyclist'),
#  ('scene-0769',
#   'Truck, parked cars, ped crossing crosswalk, turn right, parking lot'),
#  ('scene-0770', 'Stationary ego vehicle, parking lot, ped on road'),
#  ('scene-0771',
#   'Stationary ego vehicle, person getting out of ego vehicle, parking lot, peds'),
#  ('scene-0775',
#   'Stationary ego vehicle, parking lot, peds, truck, cars pass by'),
#  ('scene-0777',
#   'Stationary ego vehicle, parking lot, person getting inside ego vehicle'),
#  ('scene-0778', 'Parking lot, U turn, parked cars, peds'),
#  ('scene-0789', 'Wait at intersection, ped crossing crosswalk, parking lot'),
#  ('scene-0799',
#   'Cars, cross intersection, motorcycle overtaking us, parking lot, truck, arrive at intersection'),
#  ('scene-0802',
#   'Cones, cross intersection, peds on sidewalk, parking lot, parked bicycle'),
#  ('scene-0815',
#   'Rain, wait at intersection, truck, turn right, parking lot, cross intersection, change lanes, parked bicycle, parked cars'),
#  ('scene-0817', 'Trailer, parking lots, cones, bridge, trucks, peds'),
#  ('scene-0819', 'Rain, trucks, parking lot, wait at intersection, turn right'),
#  ('scene-0820',
#   'Rain, Cross intersection, cross intersection, parking lots, peds on sidewalk, low traffic density, parked cars'),
#  ('scene-0821',
#   'Parking lot, parked trucks, trailers, cones, barrier, cross roundabout'),
#  ('scene-0860',
#   'Parking lot, peds on sidewalk, jaywalker, parked bicycle, arrive at intersection, wait'),
#  ('scene-0864',
#   'Car passing by, parking lot, cones, bus passing by, many peds, parked truck'),
#  ('scene-0865',
#   'Many peds, parking lot, parked bicycle, bus, parked motorcycles, turn right, cross intersection, stopped truck, people on truck'),
#  ('scene-0866',
#   'Cross intersection, parking lot, peds on sidewalk, parked motorcycle'),
#  ('scene-0869',
#   'Rain, peds, bridge, parked cars, parking lot, bicycle rack, jaywalker, parked bicycle'),
#  ('scene-0872',
#   'Rain, peds, truck, wait at red light, parked cars, parking lot, parked bicycle'),
#  ('scene-0873',
#   'Rain, waiting at intersection, jaywalkers, peds, parking lot, bus'),
#  ('scene-0876',
#   'Rain, construction site, cones, barriers, construction worker, parked cars, parking lot, bridge, peds'),
#  ('scene-0877',
#   'Rain, parked cars, barriers, cones, containers, truck, person standing on truck, ped, construction site, construction vehicle, parking lot, bus'),
#  ('scene-0882',
#   'Rain, wait at intersection, truck, parked cars, peds, parking lot, turn left'),
#  ('scene-0883', 'Rain, peds, parking lot, truck, waiting at intersection'),
#  ('scene-0888',
#   'Rain, peds, truck, cones, parked cars, turn right, parking lot, animal'),
#  ('scene-0889',
#   'Rain, wait at intersection, bicycle racks, peds, ped with umbrella, ped crossing crosswalk, ped with bag, parking lot, truck'),
#  ('scene-0890',
#   'Rain, parking lot, parked cars, truck, wait at intersection, parked bicycles, peds, barriers'),
#  ('scene-0891',
#   'Rain, parking lot, parked bicycles, parked cars, bicycle rack, turn left, peds, ped crossing crosswalk, cross intersection, barriers'),
#  ('scene-0892',
#   'Rain, parked cars, barriers, peds, parked bicycle, parked scooter, bicycle rack, parking lot, crossing intersection'),
#  ('scene-0895',
#   'Rain, parked cars, cones, peds, car leaving parking garage, cross intersection, construction site, construction vehicle, barrier'),
#  ('scene-0896',
#   'Rain, parked cars, peds, construction, fence, flooded road, construction vehicle, truck, parked motorcycles, narrow street, bus, parking lot'),
#  ('scene-0897',
#   'Rain, parked cars, parking lot, ped crossing crosswalk, peds'),
#  ('scene-0899',
#   'Rain, parked cars, peds, cross intersection, parking lot, truck, parked bicycle'),
#  ('scene-0900',
#   'Rain, parked cars, peds, parked bicycle, parking lot, truck, turn left'),
#  ('scene-0901',
#   'Rain, parked cars, parking lot, peds, ped crossing crosswalk'),
#  ('scene-0906',
#   'Rain, parked cars, parked bicycle, peds, cones, cross intersection, parking lot, turning right'),
#  ('scene-0907',
#   'Rain, turn right, parked cars, parking lot, peds, bus, truck, waiting'),
#  ('scene-0909',
#   'Rain, ped, cones, parked cars, construction site, construction vehicle, parking lot, barriers'),
#  ('scene-0912',
#   'Rain, parked cars, trucks, parking lot, construction vehicle'),
#  ('scene-0913',
#   'Rain, parked cars, semi trailers, barriers, construction vehicle, parking lot, parked buses'),
#  ('scene-0914',
#   'Rain, parking lot, bicycle rack, buses, jaywalker, parked scooter, arrive at intersection'),
#  ('scene-0916',
#   'Parking lot, bicycle rack, parked bicycles, bus, many peds, parked scooters, parked motorcycle'),
#  ('scene-0917', 'Peds, jaywalkers, nature, parking lot, bus, turn left'),
#  ('scene-0919', 'Greeneries, parking lot, parked car, ped, motorcycle'),
#  ('scene-0924',
#   'Cleaner cleaning street, nature, parked car, trash can, parked vehicles, parked bicycle, parking lot, bump, parked bicycle'),
#  ('scene-0931',
#   'Turn right, parked scooters, nature, parking lot, peds, bump, arrive at parking bay'),
#  ('scene-0949',
#   'Parking lot, barriers, people at parking lot, parked bicycle, cones, peds, jaywalker'),
#  ('scene-0966',
#   'Many peds, construction, peds unloading trucks, narrow road, avoidance, parked scooter, parking lot, parked bicycles'),
#  ('scene-0969',
#   'Cones, cars, many peds, changing lane, parking lot, parked cars, parked motorcycles'),
#  ('scene-0988',
#   'Parking lot, turn right, cross intersection, parked bicycle, parked motorcycle, peds'),
#  ('scene-0990', 'Parked bicycles, peds on sidewalk, parking lot, barrier'),
#  ('scene-0991', 'Parking lot, cones, ped on sidewalk'),
#  ('scene-1004', 'Night, many peds, parking lots'),
#  ('scene-1005', 'Night, bus, peds, crosswalk, parking lot'),
#  ('scene-1008', 'Night, peds in dark, lights, scooters, parking garage'),
#  ('scene-1009',
#   'Night, peds on sidewalk, slope, motorcycles, parking garage, parked cars'),
#  ('scene-1064',
#   'Night, trash cans, wait for scooter, turn right, parking lot'),
#  ('scene-1085',
#   'Night, many peds, parked bicycles, turn left, parked scooters, congestion, peds with bags, cars in parking garage on second floor, trash cans')]

# %%
print(len(find_scenes_by_desc(['stationary ego'])))
(find_scenes_by_desc(['stationary ego']))
# Out:
# 4
# [('scene-0770', 'Stationary ego vehicle, parking lot, ped on road'),
#  ('scene-0771',
#   'Stationary ego vehicle, person getting out of ego vehicle, parking lot, peds'),
#  ('scene-0775',
#   'Stationary ego vehicle, parking lot, peds, truck, cars pass by'),
#  ('scene-0777',
#   'Stationary ego vehicle, parking lot, person getting inside ego vehicle')]

# %%
scenes = find_scenes_by_desc(['arrive'])
print(len(scenes))
scenes
# Out:
# 56
# [('scene-0004',
#   'Random scene, arrive at intersection, cross intersection, jaywalkers'),
#  ('scene-0041', 'Turn left, arrive at busy intersection, red light'),
#  ('scene-0051', 'Pass parked vehicles, peds, arrive at intersection'),
#  ('scene-0176',
#   'Parked cars, extra-long bendy bus, banners, arrive at intersection, turn right, truck'),
#  ('scene-0224',
#   'Peds crossing crosswalk, arrive at intersection, barrier, ped with backpack, heavy truck'),
#  ('scene-0252',
#   'Many peds, parked bicycles, jaywalkers, arrive at intersection, cars'),
#  ('scene-0254',
#   'Parked cars, long corridor, parking lot, flag, arrive at intersection'),
#  ('scene-0287',
#   'Overtake heavy truck, stopped motorcycle, parking lot, peds, arrive at intersection'),
#  ('scene-0294',
#   'Bridge, skateboarder, wheelchair, peds, truck, arrive at intersection, parked cars'),
#  ('scene-0301',
#   'Arrive at intersection, ped loading car trunk, ped with dog crossing crosswalk, bus'),
#  ('scene-0356',
#   'Arrive at intersection, construction, digger turning, peds crossing, bus'),
#  ('scene-0368', 'Arrive at busy intersection'),
#  ('scene-0388', 'Cross intersection, bridge, arrive at intersection'),
#  ('scene-0419',
#   'Residential area, trash cans, stroller, arrive at intersection'),
#  ('scene-0420',
#   'Exit parking lot, turn left, peds, parked bicycle, arrive at intersection'),
#  ('scene-0422', 'Buses, overtake stopped car, peds, arrive at intersection'),
#  ('scene-0436', 'Turn left, scooter, arrive at intersection'),
#  ('scene-0463',
#   'Rain, FedEx truck loaded on trailer, true cone loaded on a van, arrive at intersection, parked cars, several active trucks'),
#  ('scene-0502',
#   'Parked truck, right turn, jaywalkers, bike rack, arrive at intersection'),
#  ('scene-0560',
#   'Arrive at intersection, parked cars, statue, peds, ped with stroller, flag, bendy bus'),
#  ('scene-0594', 'Rain, turn right, arrive at intersection, big trucks'),
#  ('scene-0639', 'Rain, arrive at intersection, parked vehicle'),
#  ('scene-0641',
#   'Rain, cross intersection, parked cars, change lane, arrive at intersection'),
#  ('scene-0650', 'Rain, reflections, parking lot, arrive at intersection'),
#  ('scene-0671',
#   'Cars, heavy truck, personal mobility, arrive at intersection, peds'),
#  ('scene-0688', 'Arrive at intersection, many peds, cyclist, bicycle'),
#  ('scene-0698',
#   'Pullable object, peds on sidewalk, parked cars, parking lot, truck, arrive at intersection, cone'),
#  ('scene-0700',
#   'Overtake stopped cars, arrive at intersection, car overtaking us, barriers, turn right, stopped cars at red light, ped on sidewalk, parking lot, bus stop'),
#  ('scene-0701',
#   'Parked cars, ped on sidewalk, bicycle, car overtaking us, ped on sidewalk, parking lot, arrive at intersection, wait at intersection'),
#  ('scene-0704',
#   'Cars, bicycles, peds on sidewalk, parking lot, arrive at intersection, wait at intersection, truck, motorcycle'),
#  ('scene-0707',
#   'Construction, peds on sidewalk, arrive at intersection, bicyclist on sidewalk, cross intersection, bus stop, parked cars'),
#  ('scene-0708',
#   'Parked cars, peds on sidewalk, cones, ped on sidewalk, arrive at intersection, cross intersection'),
#  ('scene-0712',
#   'Cones, cars, peds on sidewalk, truck, construction vehicle, arrive at intersection, cross intersection, change lane, pole, bridge'),
#  ('scene-0713',
#   'Bridge, cars, peds on sidewalk, truck, arrive at intersection, peds crossing crosswalk'),
#  ('scene-0744',
#   'Parked cars, parking lot, change lane and change back, arrives at intersection'),
#  ('scene-0746',
#   'Parked cars, parking lot, parked trucks, container, peds, arrive at intersection, wait at intersection'),
#  ('scene-0757',
#   'Arrive at busy intersection, bus, wait at intersection, bicycle, peds'),
#  ('scene-0783',
#   'Cars, parked cars, overtaking a bus, peds, parked scooter, truck, arrive at intersection, cones'),
#  ('scene-0799',
#   'Cars, cross intersection, motorcycle overtaking us, parking lot, truck, arrive at intersection'),
#  ('scene-0810',
#   'Rain. Truck, buses, cars, peds, jaywalker, arrive at intersection'),
#  ('scene-0852',
#   'Many peds, jaywalkers, cars, parked motorcycle, truck, arrive at intersection'),
#  ('scene-0854',
#   'Lane change, dense traffic, buses, cars, ped, arrive at intersection'),
#  ('scene-0860',
#   'Parking lot, peds on sidewalk, jaywalker, parked bicycle, arrive at intersection, wait'),
#  ('scene-0886',
#   'Rain, peds, truck, ships, cones, parked cars, barriers, arrive at intersection'),
#  ('scene-0904',
#   'Rain, parked cars, bus, peds, barriers, cross intersection, ped crossing crosswalk, construction site, cones, scooter, arrive at intersection'),
#  ('scene-0914',
#   'Rain, parking lot, bicycle rack, buses, jaywalker, parked scooter, arrive at intersection'),
#  ('scene-0931',
#   'Turn right, parked scooters, nature, parking lot, peds, bump, arrive at parking bay'),
#  ('scene-0982',
#   'Truck, barrier, many peds, cones, cars, wait behind intersection, construction vehicle, arrive at intersection'),
#  ('scene-1021', 'Night, peds in dark, arrive at intersection, bus'),
#  ('scene-1044',
#   'Night, motorcycles, dense traffic, congestion, arrive at intersection'),
#  ('scene-1067', 'Night, rain, bump, ped in dark, arrive at intersection'),
#  ('scene-1079', 'Night, big street, high speed, arrive at intersection'),
#  ('scene-1081',
#   'Night, rain, big street, congestion, cars, scooter, arrive at intersection'),
#  ('scene-1092',
#   'Night, many peds, many trash cans, ped with bag, stopped taxi, delivery scooter, arrive at intersection'),
#  ('scene-1095',
#   'Night, rain, lane change, cross intersection, scooter, bus, arrive at intersection'),
#  ('scene-1102',
#   'Night, rain, scooter, cars, high speed, cross intersection, arrive at intersection')]

# %%
scenes = find_scenes_by_desc(['reverse'])
print(len(scenes))
scenes
# Out:
# 2
# [('scene-0373',
#   'Parking lot, peds, construction, a car doing reverse parking'),
#  ('scene-0374', 'Parking lot, vehicle reverses into parking spot')]

# %%
find_scenes_by_name('0771')
# Out:
# [('scene-0771',
#   'Stationary ego vehicle, person getting out of ego vehicle, parking lot, peds')]

# %%
scenes = find_scenes_by_desc([''])
len(scenes)
# Out:
# 13

# %%
nusc.render_scene()
