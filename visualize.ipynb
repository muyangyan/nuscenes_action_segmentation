# %%
import matplotlib.pyplot as plt
import tqdm
import numpy as np

from nuscenes.nuscenes import NuScenes
from nuscenes.map_expansion.map_api import NuScenesMap
from nuscenes.map_expansion import arcline_path_utils
from nuscenes.map_expansion.bitmap import BitMap
from nuscenes.can_bus.can_bus_api import NuScenesCanBus

dataroot='/data/Datasets/nuscenes'

nusc = NuScenes(version='v1.0-trainval', dataroot=dataroot, verbose=True)
nusc_map = NuScenesMap(dataroot=dataroot, map_name='singapore-onenorth')
nusc_can = NuScenesCanBus(dataroot=dataroot)
# Out:
# ======
# Loading NuScenes tables for version v1.0-trainval...
# 23 category,
# 8 attribute,
# 4 visibility,
# 64386 instance,
# 12 sensor,
# 10200 calibrated_sensor,
# 2631083 ego_pose,
# 68 log,
# 850 scene,
# 34149 sample,
# 2631083 sample_data,
# 1166187 sample_annotation,
# 4 map,
# Done loading in 41.670 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 13.1 seconds.
# ======

# %%
def find_scenes_by_name(name):
    return [ i for i in nusc.scene if name in i['name'].lower() ]

# %%
scene = find_scenes_by_name('0771')[0]
first_sample_token = scene['first_sample_token']

# %%
nusc.render_sample(first_sample_token)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1987698/1635313058.py in <module>
# ----> 1 nusc.render_sample(first_sample_token)
#
# ~/miniconda3/envs/nuscenes/lib/python3.7/site-packages/nuscenes/nuscenes.py in render_sample(self, sample_token, box_vis_level, nsweeps, out_path, show_lidarseg, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose, show_panoptic)
#     544                                     show_lidarseg=show_lidarseg, filter_lidarseg_labels=filter_lidarseg_labels,
#     545                                     lidarseg_preds_bin_path=lidarseg_preds_bin_path, verbose=verbose,
# --> 546                                     show_panoptic=show_panoptic)
#     547
#     548     def render_sample_data(self, sample_data_token: str, with_anns: bool = True,
#
# ~/miniconda3/envs/nuscenes/lib/python3.7/site-packages/nuscenes/nuscenes.py in render_sample(self, token, box_vis_level, nsweeps, out_path, show_lidarseg, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose, show_panoptic)
#    1116             for i, (_, sd_token) in enumerate(radar_data.items()):
#    1117                 self.render_sample_data(sd_token, with_anns=i == 0, box_vis_level=box_vis_level, ax=ax, nsweeps=nsweeps,
# -> 1118                                         verbose=False)
#    1119             ax.set_title('Fused RADARs')
#    1120
#
# ~/miniconda3/envs/nuscenes/lib/python3.7/site-packages/nuscenes/nuscenes.py in render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map, use_flat_vehicle_coordinates, show_lidarseg, show_lidarseg_legend, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose, show_panoptic)
#    1297                 # Get aggregated radar point cloud in reference frame.
#    1298                 # The point cloud is transformed to the reference frame for visualization purposes.
# -> 1299                 pc, times = RadarPointCloud.from_file_multisweep(self.nusc, sample_rec, chan, ref_chan, nsweeps=nsweeps)
#    1300
#    1301                 # Transform radar velocities (x is front, y is left), as these are not transformed when loading the
#
# ~/miniconda3/envs/nuscenes/lib/python3.7/site-packages/nuscenes/utils/data_classes.py in from_file_multisweep(cls, nusc, sample_rec, chan, ref_chan, nsweeps, min_distance)
#      99         for _ in range(nsweeps):
#     100             # Load up the pointcloud and remove points close to the sensor.
# --> 101             current_pc = cls.from_file(osp.join(nusc.dataroot, current_sd_rec['filename']))
#     102             current_pc.remove_close(min_distance)
#     103
#
# ~/miniconda3/envs/nuscenes/lib/python3.7/site-packages/nuscenes/utils/data_classes.py in from_file(cls, file_name, invalid_states, dynprop_states, ambig_states)
#     384
#     385         meta = []
# --> 386         with open(file_name, 'rb') as f:
#     387             for line in f:
#     388                 line = line.strip().decode('utf-8')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/Datasets/nuscenes/samples/RADAR_FRONT/n008-2018-08-30-15-31-50-0400__RADAR_FRONT__1535657569023873.pcd'
